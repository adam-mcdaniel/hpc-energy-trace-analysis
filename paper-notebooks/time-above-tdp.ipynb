# %% [markdown]
# # Imports

# %%
from IPython.display import Image, display, SVG, HTML
from typing import Dict, List, Tuple, Generator, Optional

# from interval_timeline import CallGraph
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os
import re
import time
import datetime

from tqdm import tqdm
import otf2
import hatchet as ht
import thicket as tt
from collections import defaultdict
# Out:
# Warning: Roundtrip module could not be loaded. Requires jupyter notebook version <= 7.x.

# %%
# Track how long the notebook takes to run
NOTEBOOK_START_TIME = time.time()
print(f"Notebook started at {NOTEBOOK_START_TIME} ({datetime.datetime.fromtimestamp(NOTEBOOK_START_TIME)})")
# Out:
# Notebook started at 1761069217.0607529 (2025-10-21 13:53:37.060753)

# %% [markdown]
# # Preamble

# %% [markdown]
# ### Define The Name of the Cluster & Trace Paths
#
# Define the name of the cluster and the paths to the trace files.
# This is needed to parse the trace directory paths correctly as generated by the master run script.

# %%
CLUSTER_NAME = "frontier"

ROOT_TRACE_DIR = "../frontier-results"

# %% [markdown]
# ### Define Which Ranks Run on Each Node
#
# Define the topology of the runs. This is needed to attribute energy consumption correctly. Metrics are gathered at the node level, so we
# need to know which node each rank ran on to get the metrics associated with that node + rank.

# %%
HPL_NODE_RANKS = {
	'node0': ['MPI Rank 0', 'MPI Rank 1', 'MPI Rank 2', 'MPI Rank 3', 'MPI Rank 4', 'MPI Rank 5', 'MPI Rank 6', 'MPI Rank 7'],
}
HPG_NODE_RANKS = HPL_NODE_RANKS

# %% [markdown]
# ### Define The Metrics to Attribute to Each Rank
#
# This defines which MPI rank is on which GCD (frontier) or APU (el capitan). Two ranks drawing from the same GPU (each GPU has 2 GCDs) will have their energy consumption estimated independently based on their exclusive runtime.

# %%
HPL_RANKS_TO_METRICS = {
	'MPI Rank 0': ['A2rocm_smi:::energy_count:device=4'],
	'MPI Rank 1': ['A2rocm_smi:::energy_count:device=4'],
	'MPI Rank 2': ['A2rocm_smi:::energy_count:device=2'],
	'MPI Rank 3': ['A2rocm_smi:::energy_count:device=2'],
	'MPI Rank 4': ['A2rocm_smi:::energy_count:device=6'],
	'MPI Rank 5': ['A2rocm_smi:::energy_count:device=6'],
	'MPI Rank 6': ['A2rocm_smi:::energy_count:device=0'],
	'MPI Rank 7': ['A2rocm_smi:::energy_count:device=0'],
}

HPG_RANKS_TO_METRICS = HPL_RANKS_TO_METRICS

# %% [markdown]
# ### Define Which Metrics to Track in the Traces
#
# This defines the metrics we're going to pay attention to when parsing the traces.
# All metrics that are used above must be included here.

# %%
METRICS_TO_TRACK = [
    'A2rocm_smi:::energy_count:device=0',
    'A2rocm_smi:::energy_count:device=2',
    'A2rocm_smi:::energy_count:device=4',
    'A2rocm_smi:::energy_count:device=6',
    
    'A2coretemp:::craypm:accel0_energy',
    'A2coretemp:::craypm:accel1_energy',
    'A2coretemp:::craypm:accel2_energy',
    'A2coretemp:::craypm:accel3_energy',
    
    'A2coretemp:::craypm:accel0_power',
    'A2coretemp:::craypm:accel1_power',
    'A2coretemp:::craypm:accel2_power',
    'A2coretemp:::craypm:accel3_power',

    'A3coretemp:::craypm:accel0_energy',
    'A3coretemp:::craypm:accel1_energy',
    'A3coretemp:::craypm:accel2_energy',
    'A3coretemp:::craypm:accel3_energy',
    
    'A2coretemp:::craypm:accel0_energy_timestamp',
    'A2coretemp:::craypm:accel1_energy_timestamp',
    'A2coretemp:::craypm:accel2_energy_timestamp',
    'A2coretemp:::craypm:accel3_energy_timestamp',
    'A2coretemp:::craypm:freshness'
]

# %%
# Glob everything from `./scorep-traces/frontierXXXXX-rochpl-*`
ROCHPL_BASE = "rochpl-r8--P_1_-Q_8_-N_245760"
ROCHPL_MXP_BASE = "rochplmxp-r8--P_1_-Q_8_-N_245760"
HPG_BASE = "xhpgmp-r8-128_128_128_--run_type=standalone_ref"
HPG_MXP_BASE = "xhpgmp-r8-128_128_128_--run_type=standalone_mxp"

ROCHPL_TRACES = [
    f"{ROOT_TRACE_DIR}/{ROCHPL_BASE}/{d}/traces.otf2"
	for d in os.listdir(f"{ROOT_TRACE_DIR}/{ROCHPL_BASE}/")
	if re.match(rf"trial_\d+-{CLUSTER_NAME}\d+.*-rochpl-.*", d) and os.path.isdir(f"{ROOT_TRACE_DIR}/{ROCHPL_BASE}/{d}")
]

ROCHPL_MXP_TRACES = [
    f"{ROOT_TRACE_DIR}/{ROCHPL_MXP_BASE}/{d}/traces.otf2"
	for d in os.listdir(f"{ROOT_TRACE_DIR}/{ROCHPL_MXP_BASE}/")
	if re.match(rf"trial_\d+-{CLUSTER_NAME}\d+.*-rochplmxp-.*", d) and os.path.isdir(f"{ROOT_TRACE_DIR}/{ROCHPL_MXP_BASE}/{d}")
]

HPG_TRACES = [
    f"{ROOT_TRACE_DIR}/{HPG_BASE}/{d}/traces.otf2"
	for d in os.listdir(f"{ROOT_TRACE_DIR}/{HPG_BASE}/")
	if re.match(rf"trial_\d+-{CLUSTER_NAME}\d+.*-xhpgmp-.*--run_type=standalone_ref", d) and os.path.isdir(f"{ROOT_TRACE_DIR}/{HPG_BASE}/{d}")
]

HPG_MXP_TRACES = [
    f"{ROOT_TRACE_DIR}/{HPG_MXP_BASE}/{d}/traces.otf2"
	for d in os.listdir(f"{ROOT_TRACE_DIR}/{HPG_MXP_BASE}/")
	if re.match(rf"trial_\d+-{CLUSTER_NAME}\d+.*-xhpgmp-.*--run_type=standalone_mxp", d) and os.path.isdir(f"{ROOT_TRACE_DIR}/{HPG_MXP_BASE}/{d}")
]

print("ROCHPL_TRACES:", len(ROCHPL_TRACES))
print("ROCHPL_MXP_TRACES:", len(ROCHPL_MXP_TRACES))
print("HPG_TRACES:", len(HPG_TRACES))
print("HPG_MXP_TRACES:", len(HPG_MXP_TRACES))
# Out:
# ROCHPL_TRACES: 4
# ROCHPL_MXP_TRACES: 4
# HPG_TRACES: 4
# HPG_MXP_TRACES: 4

# %% [markdown]
# ### Metrics
# Which metrics to trace, and functions for reading/writing them to CSVs.

# %%
# def callgraph_to_csv(call_graph: CallGraph, group: str, thread: str, filename: str):
#     """Convert a CallGraph to a CSV file."""
#     with open(filename, 'w') as f:
#         f.write("Thread,Group,Depth,Name,Start Time,End Time,Duration\n")
#         intervals = call_graph.get_intervals_between(float('-inf'), float('inf'))
        
#         for interval in intervals:
#             start = interval.start
#             end = interval.end or float('inf')
#             duration = end - start
#             name = interval.name if interval.name else "Unknown"
#             depth = interval.depth if interval.depth else 0

#             f.write(f"{thread},{group},{depth},\"{name}\",{start},{end},{duration}\n")

# def metrics_to_csv(group: str, thread_metrics: Dict[str, List[Tuple[float, float]]], filename: str):
#     """Convert metrics to a CSV file."""
#     with open(filename, 'w') as f:
#         f.write("Group,Metric Name,Time,Value\n")
#         for metric_name, values in thread_metrics.items():
#             for time, value in values:
#                 f.write(f"{group},{metric_name},{time},{value}\n")

def read_metrics_dataframe(file: str) -> pd.DataFrame:
    df = pd.read_csv(file)
    # For all the rocm metrics, divide by 1e6 to convert from uJ to J
    for metric_name in df['Metric Name'].unique():
        if 'rocm_smi:::energy_count:device' in metric_name:
            df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
    return df

def read_call_graph_dataframe(file: str) -> pd.DataFrame:
    return pd.read_csv(file)

# %% [markdown]
# ### Remove Conflicting CSVs
# Remove any existing CSVs that might conflict with new ones to be generated.

# %%
# Remove all the old CSV files
for file in os.listdir('.'):
    if file.endswith('.csv'):
        os.remove(file)

# %% [markdown]
# ### Setup for Loading Traces
# Convert an OTF2 to a CSV dataset to be loaded into a dataframe

# %%
def trace_to_csv(trace: str, processes_to_track: List[str], metrics_to_track: List[str] = METRICS_TO_TRACK, cray_time_offset=0.0):
    # Remove all the old CSV files
    for file in os.listdir('.'):
        if file.endswith('.csv'):
            os.remove(file)
    print(f'Tracking metrics: {metrics_to_track}')
    # Shell out to ./trace_to_csv_parallel binary with `./trace_to_csv_parallel --tracePath=/path/to/trace.otf2`
    cmd = f'./trace_to_csv_parallel --trace={trace} --metrics="{",".join(metrics_to_track)}"'
    print(f"Running command: {cmd}")
    os.system(cmd)

# Visualize the dataframes
def visualize_dataframe(df):
    """Visualize the first few rows of a DataFrame as HTML."""
    # pd.set_option("display.width", 2400)
    # pd.set_option("display.max_colwidth", 100)
    # pd.set_option("display.max_rows", 20)
    
    display(HTML(df.head(n=20).to_html(index=False)))

# %% [markdown]
# ### Math Helpers
#
# Helpers for linearly interpolating values and computing numerical integrals + derivatives

# %%
def sampled_to_continuous(df, time_col='Time', value_col='Value'):
    t_samples = df[time_col].astype(float)
    y = df[value_col].astype(float)
    # Apply a savgol filter to smooth the data
    # y = scipy.signal.savgol_filter(y, window_length=11, polyorder=2, mode='nearest')
    # Apply a median filter to smooth the data
    # y = scipy.signal.medfilt(y, kernel_size=11)
 
    # Create a continuous function that interpolates the sampled data
    f = lambda t: np.interp(t, t_samples, y)
    return f

def numerical_derivative(func, h=1e-5):
    """Compute the numerical derivative of a function at a point t."""
    return lambda t: (func(t + h) - func(t - h)) / (2 * h)

def numerical_integral(f, a=0.0, dx=1e-1):
    """
    Return a function F(x) that approximates the integral of f(t) dt from t=a to t=x,
    using the trapezoidal rule in a fully vectorized manner.
    The function F(x) will return a scalar when x is a scalar, and an array
    when x is an array.
    """
    # Determinar si f soporta arrays de NumPy
    try:
        _ = f(np.array([a, a + dx]))
        f_np = f
    except Exception:
        f_np = np.vectorize(f)
    
    def F(x):
        x_arr = np.atleast_1d(x).astype(float)
        # Manejo de x < a invirtiendo signo
        sign = np.ones_like(x_arr)
        mask = x_arr < a
        sign[mask] = -1
        x_pos = np.where(mask, a + (a - x_arr), x_arr)
        
        # Grid hasta el máximo de x
        xmax = x_pos.max()
        t = np.arange(a, xmax + dx, dx)
        u = f_np(t)
        
        # Suma acumulada de trapecios
        trap_heights = (u[:-1] + u[1:]) / 2
        cum = np.concatenate(([0], np.cumsum(trap_heights * dx)))
        
        # Índices y remanentes
        idx = ((x_pos - a) // dx).astype(int)
        rem = x_pos - (a + idx * dx)
        
        # Valores en fronteras
        f_end = f_np(x_pos)
        f_start = u[idx]
        
        # Integral aproximada
        integral = cum[idx] + (f_start + f_end) * rem / 2
        result = sign * integral
        
        # Devolver escalares cuando corresponda
        return result.item() if np.isscalar(x) else result
    
    return F
        
def unwrap_or_zero(f):
    if not f:
        return 0.0
    else:
        return f

# %% [markdown]
# ### Thicket + Hatchet Integration
# Convert the CSV datasets into thicket/hatchet objects for analysis

# %%
def create_hatchet_dag(call_graph_df: pd.DataFrame, metric_functions: Dict[str, callable]):
    df = call_graph_df.copy()
    # Asume que viene “bien formado”: cada fila es una invocación con Depth que respeta el anidamiento.
    # Si no está ordenado por Start Time, ordénalo una vez.
    df = df.sort_values(by='Start Time')

    # Filtrado opcional por duración, replica tu lógica si quieres:
    df = df[df['Duration'] >= 0.001]

    pref3 = df['Name'].str[:3].str.lower()
    df = df[~pref3.isin(['hip', 'mpi'])]
    
    # Vectoriza cálculo de métricas por fila (Δ = f(end) - f(start))
    starts = df['Start Time'].to_numpy()
    ends   = df['End Time'].to_numpy()
    names  = df['Name'].to_numpy()
    depths = df['Depth'].to_numpy()
    durs   = df['Duration'].to_numpy()


    metrics_cols = {}
    for metric, f in tqdm(metric_functions.items()):
        try:
            vals = f(ends) - f(starts)            # ideal: f soporta arrays
            vals = np.asarray(vals, dtype=float)
            vals = np.nan_to_num(vals, nan=0.0, posinf=0.0, neginf=0.0)
        except Exception:
            # Fallback si f no vectoriza
            vals = np.fromiter(
                (unwrap_or_zero(f(e) - f(s)) for s, e in zip(starts, ends)),
                dtype=float, count=len(starts)
            )
        metrics_cols[metric] = vals

    # Construcción del DAG con una pila indexada por profundidad
    # Mantenemos las referencias a los últimos nodos por cada Depth.
    # Cuando Depth sube, el nuevo nodo se anexa como hijo del nodo en Depth-1.
    dag_roots: list = []
    last_at_depth: dict[int, dict] = {}

    # Usamos itertuples para bajo overhead
    M = len(df)
    for i, (name, depth, dur) in enumerate(zip(names, depths, durs)):
        node_metrics = {'time (inc)': float(dur), 'time': 0.0}
        for m, arr in metrics_cols.items():
            node_metrics[m] = float(arr[i])

        node = {'frame': {'name': name}, 'metrics': node_metrics, 'children': []}

        if depth == 0 or (depth - 1) not in last_at_depth:
            dag_roots.append(node)
        else:
            parent = last_at_depth[depth - 1]
            parent['children'].append(node)

        last_at_depth[depth] = node

        # Si retrocede la profundidad en la siguiente fila, iremos sobreescribiendo last_at_depth
        # No hace falta “cerrar” nada aún; calculamos 'time' más adelante en una segunda pasada.

    # Segunda pasada postorden para calcular 'time' = 'time (inc)' - suma hijos.
    # Podemos hacerlo con una DFS iterativa.
    stack = [(root, False) for root in dag_roots]
    while stack:
        node, visited = stack.pop()
        if not visited:
            stack.append((node, True))
            for ch in node['children']:
                stack.append((ch, False))
        else:
            child_incs = 0.0
            for ch in node['children']:
                child_incs += ch['metrics']['time (inc)']
            node['metrics']['time'] = node['metrics']['time (inc)'] - child_incs

    return dag_roots

# %% [markdown]
# # Hierarchical DataFrames
#
# Organize the data into hierarchical dataframes for easier analysis:
# - `Ensemble`: all the runs of a given configuration
# - `Run`: a single run of a configuration
# - `Node`: a single node in a run
# - `Rank`: a single MPI rank in a node

# %%
class Rank:
	def __init__(self, node: str, name: str, call_graph_df: pd.DataFrame):
		self.node = node
		self.name = name
		self.call_graph = call_graph_df
		assert self.call_graph.columns.tolist() == ['Thread', 'Group', 'Depth', 'Name', 'Start Time', 'End Time', 'Duration'], f"Call graph DataFrame has incorrect columns, found {call_graph_df.columns.tolist()}"
		
	def get_all_code_regions(self) -> List[str]:
		return self.call_graph['Name'].unique().tolist()

	def compute_attribution(
		self,
		metrics_accumulated: Dict[str, callable],
		duration_threshold: float = 0.001,
		weights_by_metric: Optional[Dict[str, np.ndarray]] = None):
		df = self.call_graph
		df = df[df['Duration'] >= duration_threshold]
		pref3 = df['Name'].str[:3].str.lower()
		df = df[~pref3.isin(['hip', 'mpi'])]

		if df.empty:
			return pd.DataFrame(columns=['Code Region'] + list(metrics_accumulated.keys()))

		starts = df['Start Time'].to_numpy()
		ends   = df['End Time'].to_numpy()
		names  = df['Name'].to_numpy()

		cols = {}
		for metric, f in metrics_accumulated.items():
			try:
				deltas = f(ends) - f(starts)
				deltas = np.asarray(deltas, dtype=float)
				deltas = np.nan_to_num(deltas, nan=0.0, posinf=0.0, neginf=0.0)
			except Exception:
				deltas = np.fromiter(
					(unwrap_or_zero(f(e) - f(s)) for s, e in zip(starts, ends)),
					dtype=float, count=len(starts)
				)

			# Apply weights if present for this metric (1.0 if not provided)
			if weights_by_metric and metric in weights_by_metric:
				w = np.asarray(weights_by_metric[metric], dtype=float)
				if w.shape[0] == deltas.shape[0]:
					deltas = deltas * w
				elif w.size == 1:
					deltas = deltas * float(w)
				else:
					# Safe fallback if the length does not match for some reason
					deltas = deltas * 1.0

			cols[metric] = deltas

		out = pd.DataFrame(cols)
		out['Code Region'] = names
		# Aggregate by region
		out = out.groupby('Code Region', as_index=False).sum()
		return out

	def refresh(self):
		return Rank(self.node, self.name, self.call_graph)

	def __str__(self):
		return f"Rank({self.name})"

def build_inclusive_masks_for_rank(breaks, s, e, names, depths):
    """
    For each segment [breaks[i], breaks[i+1]), return a dict:
      masks[region_name][i] = True  iff the region is on the call stack
                                   (ancestor of top-of-stack) for the ENTIRE segment.
    Assumptions:
      - breaks includes all start/end times (so inside a segment no boundary occurs).
      - 'depths' is 0-based, increasing with nesting.
    """
    seg_count = breaks.size - 1
    masks = defaultdict(lambda: np.zeros(seg_count, dtype=bool))

    lefts, rights = breaks[:-1], breaks[1:]
    for i in range(seg_count):
        L, R = lefts[i], rights[i]

        # Regions that cover the whole segment (active across the entire segment)
        idx = np.where((s <= L) & (e >= R))[0]
        if idx.size == 0:
            continue

        # Top of stack depth
        dmax = depths[idx].max()

        # Inclusive chain = exactly one region per depth 0..dmax that covers the whole segment
        # (there should typically be at most one per depth due to proper nesting)
        for d in range(dmax + 1):
            cand = idx[depths[idx] == d]
            if cand.size:
                # If instrumentation duplicates exist at same depth, pick the one that covers the segment;
                # here cand already covers segment; pick the first deterministically.
                j = cand[0]
                masks[names[j]][i] = True

    return masks

class Node:
	def __init__(self, name: str, metrics_df: pd.DataFrame, ranks: List[Rank]):
		self.name = name
		self.ranks = ranks
		self.metrics = metrics_df
		assert self.metrics.columns.tolist() == ['Group', 'Metric Name', 'Time', 'Value'], f"Metrics DataFrame has incorrect columns, found {metrics_df.columns.tolist()}"

	def refresh(self):
		return Node(self.name, self.metrics, [rank.refresh() for rank in self.ranks])

	def get_metric_names(self) -> List[str]:
		return self.metrics['Metric Name'].unique().tolist()
	
	def get_metric_samples(self, metric_name: str) -> pd.DataFrame:
		return self.metrics[self.metrics['Metric Name'] == metric_name]

	def _filtered_callgraph(self, rank: Rank, duration_threshold: float):
		df = rank.call_graph
		df = df[df['Duration'] >= duration_threshold]
		pref3 = df['Name'].str[:3].str.lower()
		df = df[~pref3.isin(['hip', 'mpi'])]
		# Finite and non-degenerate
		mfin = np.isfinite(df['Start Time']) & np.isfinite(df['End Time'])
		df = df[mfin & (df['End Time'] > df['Start Time'])]
		return df

	def compute_attribution(
		self,
		ranks_to_metrics: Dict[str, List[str]] = {},
		instantaneous_metrics = [],
		duration_threshold: float = 0.001,
	):
		# --- Only the metrics actually used ---
		used_metrics = sorted({m for ml in ranks_to_metrics.values() for m in ml})
		if not used_metrics:
			return pd.DataFrame(columns=['Code Region'])

		# accumulated f(t) per metric (if instantaneous, integrate first)
		metrics_continuous = {m: sampled_to_continuous(self.get_metric_samples(m)) for m in used_metrics}
		metrics_accumulated = {
			m: (numerical_integral(metrics_continuous[m]) if m in instantaneous_metrics else metrics_continuous[m])
			for m in used_metrics
		}
		print(f"Node {self.name} has metrics: {list(metrics_accumulated.keys())}")

		# --- Pre-filtered by rank (and base arrays, incl. Depth) ---
		rank_df = {r.name: self._filtered_callgraph(r, duration_threshold) for r in self.ranks}
		rank_events = {
			rname: (
				df['Start Time'].to_numpy(),
				df['End Time'].to_numpy(),
				df['Name'].to_numpy(),
				df['Depth'].astype(int).to_numpy()
			)
			for rname, df in rank_df.items()
		}

		# metric -> ranks that use it
		metric_to_ranks: Dict[str, List[str]] = {}
		for rname, mlist in ranks_to_metrics.items():
			for m in mlist:
				metric_to_ranks.setdefault(m, []).append(rname)

		# Accumulator: per rank → per region → per metric → energy
		rank_tables: Dict[str, Dict[str, Dict[str, float]]] = {r.name: {} for r in self.ranks}

		# --- Loop per metric: segment time, split across ranks, and attribute inclusively ---
		for metric in used_metrics:
			f = metrics_accumulated[metric]
			rnames = [rn for rn in metric_to_ranks.get(metric, []) if rn in rank_events]
			if not rnames:
				continue

			# Global cuts (union of starts/ends of these ranks)
			all_s, all_e = [], []
			for rn in rnames:
				s, e, _, _ = rank_events[rn]
				if s.size:
					all_s.append(s); all_e.append(e)
			if not all_s:
				continue

			S_concat = np.concatenate(all_s)
			E_concat = np.concatenate(all_e)
			breaks = np.unique(np.concatenate([S_concat, E_concat]))
			breaks = breaks[np.isfinite(breaks)]
			if breaks.size < 2:
				continue
			seg_count = breaks.size - 1

			# ΔE per segment (sanitized)
			try:
				E_vals = f(breaks)
				E_vals = np.asarray(E_vals, dtype=float)
				if E_vals.shape != breaks.shape:
					raise ValueError
			except Exception:
				E_vals = np.array([float(f(float(t))) for t in breaks], dtype=float)

			dE = E_vals[1:] - E_vals[:-1]
			dE = np.nan_to_num(dE, nan=0.0, posinf=0.0, neginf=0.0)
			dE = np.maximum(dE, 0.0)

			# Which ranks are active in each segment?
			active_by_rank: Dict[str, np.ndarray] = {}
			lr_by_rank: Dict[str, Tuple[np.ndarray, np.ndarray]] = {}

			zeros_seg = np.zeros(seg_count, dtype=bool)
			for rn in rnames:
				s, e, _, _ = rank_events[rn]
				if s.size == 0:
					active_by_rank[rn] = zeros_seg
					lr_by_rank[rn] = (np.empty(0, dtype=int), np.empty(0, dtype=int))
					continue

				L = np.searchsorted(breaks, s, side='right') - 1
				R = np.searchsorted(breaks, e, side='left') - 1
				valid = (R >= L) & (R >= 0) & (L < seg_count)
				L = np.clip(L[valid], 0, seg_count - 1)
				R = np.clip(R[valid], 0, seg_count - 1)

				lr_by_rank[rn] = (L, R)

				# coverage count via difference array
				diff = np.zeros(seg_count + 1, dtype=int)
				# vectorized add/sub using slices
				# (loop remains but touches integers only; fast and cache-friendly)
				for l, r in zip(L, R):
					diff[l] += 1
					diff[r + 1] -= 1
				c = np.cumsum(diff[:-1])
				active_by_rank[rn] = (c > 0)

			# k(t): number of active ranks per segment
			k = np.zeros(seg_count, dtype=int)
			for rn in rnames:
				k += active_by_rank[rn].astype(int)

			# Energy share per segment for each rank: ΔE/k (if k==0, remains unattributed)
			share_per_seg = np.zeros_like(dE, dtype=float)
			mask_k = (k > 0)
			share_per_seg[mask_k] = dE[mask_k] / k[mask_k]

			# Inclusive attribution per rank: replicate share_per_seg to the entire inclusive chain
			for rn in rnames:
				s, e, names, depths = rank_events[rn]
				if s.size == 0:
					continue

				# Fast coverage masks per region using L/R (equivalent to inclusive chain under proper nesting):
				# region mask is True on segments where ANY of that region's events covers the whole segment.
				L, R = lr_by_rank[rn]
				masks: Dict[str, np.ndarray] = defaultdict(lambda: np.zeros(seg_count, dtype=bool))
				for j in range(L.size):
					l = L[j]; r = R[j]
					if r < l:
						continue
					masks[names[j]][l:r+1] = True

				# Add the SAME share_per_seg energy to each ancestor/region mask
				for region_name, seg_mask in masks.items():
					if not seg_mask.any():
						continue
					# sum over selected segments
					contrib = float(share_per_seg[seg_mask].sum())
					if contrib == 0.0:
						continue
					tbl = rank_tables[rn].setdefault(region_name, {})
					tbl[metric] = tbl.get(metric, 0.0) + contrib

		# --- Convert to per-rank DataFrames and do a wide merge ---
		attribution = None
		for rank in self.ranks:
			rn = rank.name
			# Filter only the metrics requested for this rank
			wanted = ranks_to_metrics.get(rn, [])
			if not wanted:
				continue

			rows = []
			for region, mdict in rank_tables.get(rn, {}).items():
				row = {'Code Region': region}
				# Ensure a column for each requested metric
				for m in wanted:
					row[m] = mdict.get(m, 0.0)
				rows.append(row)

			df_rank = pd.DataFrame(rows) if rows else pd.DataFrame({'Code Region': []})
			# Ensure columns if they are missing
			for m in wanted:
				if m not in df_rank.columns:
					df_rank[m] = 0.0

			# Rename metrics with rank suffix to avoid collisions
			rename_map = {m: f"{m}_{rn}" for m in wanted}
			df_rank = df_rank.rename(columns=rename_map)

			# Outer merge on 'Code Region'
			attribution = df_rank if attribution is None else pd.merge(
				attribution, df_rank, on='Code Region', how='outer'
			)

		# If there was nothing, return minimal header
		if attribution is None:
			all_cols = ['Code Region'] + [f"{m}_{r.name}" for r, ml in ranks_to_metrics.items() for m in ml]
			return pd.DataFrame(columns=all_cols)

		return attribution.fillna(0.0)

	def __str__(self):
		return f"Node(name={self.name}, ranks={[rank.name for rank in self.ranks]})"

class Run:
	def __init__(self, path: str, nodes: List[Node] = []):
		self.path = path
		self.nodes = nodes
		
	def refresh(self):
		return Run(self.path, [node.refresh() for node in self.nodes])

	@staticmethod
	def from_trace_path(trace_path: str, node_ranks: Dict[str, List[str]]):
		# Load the trace dataframes for each node and its ranks
		if not os.path.exists(trace_path):
			raise FileNotFoundError(f"Trace file {trace_path} does not exist.")
		# print(f"Loading trace from {trace_path} for idle period {idle_period_ms} ms and active period {active_period_ms} ms.")
		# trace_to_csv(trace_path, processes, METRICS_TO_ATTRIBUTE)
		# Load the CSV files into dataframes
		all_threads = []
		for _, ranks in node_ranks.items():
			all_threads.extend(ranks)
		result = {}
		trace_to_csv(trace_path, all_threads)
		for node, ranks in node_ranks.items():
			metrics_df = read_metrics_dataframe(f"{ranks[0]}_metrics.csv")
			print
			assert metrics_df.columns.tolist() == ['Group', 'Metric Name', 'Time', 'Value'], f"Metrics DataFrame has incorrect columns, found {metrics_df.columns.tolist()}"
			rank_callgraphs = []
			for rank in ranks:
				if os.path.exists(f"{rank}_Master_thread_callgraph.csv"):
					call_graph_df = read_call_graph_dataframe(f"{rank}_Master_thread_callgraph.csv")
					assert call_graph_df.columns.tolist() == ['Thread', 'Group', 'Depth', 'Name', 'Start Time', 'End Time', 'Duration'], f"Call graph DataFrame has incorrect columns, found {call_graph_df.columns.tolist()}"
					# Construct the Hatchet and Thicket graphs
					rank_callgraphs.append(Rank(node, rank, call_graph_df))
			result[node] = Node(node, metrics_df, rank_callgraphs)
		return Run(trace_path, list(result.values()))

	def compute_attribution(self, ranks_to_metrics: Dict[str, List[str]]={}, instantaneous_metrics=[]):
		attributions = {}
		for node in self.nodes:
			print(f"Computing attribution for node {node.name}...")
			attributions[node.name] = node.compute_attribution(ranks_to_metrics, instantaneous_metrics)
		return attributions
	
	def get_metric_samples(self, node_name: str, metric_name: str) -> pd.DataFrame:
		for node in self.nodes:
			if node.name == node_name:
				return node.get_metric_samples(metric_name)
		raise ValueError(f"Node {node_name} not found in run.")
	
	def to_thicket(self, **metadata) -> tt.Thicket:
		thickets = []
		
		for node in self.nodes:
			# self.get_metric_samples(node)
			metric_functions = {}
			for metric_name in node.get_metric_names():
				metric_functions[metric_name] = sampled_to_continuous(node.get_metric_samples(metric_name))
			
			for rank in node.ranks:
				print(f"Creating Thicket for node {node.name}, rank {rank.name}...")
				dag = create_hatchet_dag(rank.call_graph, metric_functions)
				tf = tt.Thicket.from_literal(dag)
				# tf = tt.Thicket.from_literal(dag)
				print("Thicket created from DAG.")
				tf.metadata = pd.DataFrame.from_dict(tf.profile_mapping, orient="index")
				tf.metadata['rank'] = rank.name
				tf.metadata['node'] = node.name
				tf.metadata = tf.metadata.assign(**metadata)
				tf.metadata.index.name = tf.dataframe.index.names[1]
		
				thickets.append(tf)
		
		print(f"Total thickets created: {len(thickets)}")
		if thickets:
			print("Combining thickets...")
			return tt.Thicket.concat_thickets(thickets, disable_tqdm=True)
		raise ValueError("No thickets were created from the run.")
		
	def __str__(self):
		return f"Run(path={self.path}, nodes={[str(node) for node in self.nodes]})"

class Ensemble:
	def __init__(self, runs: List[Run]):
		self.runs = runs
		self.attributions = {}
	
	@staticmethod
	def from_trace_paths(trace_paths: List[str], node_ranks: Dict[str, List[str]]):
		runs = []
		for path in trace_paths:
			print(f"Loading run from trace path: {path}")
			run = Run.from_trace_path(path, node_ranks)
			runs.append(run)
		return Ensemble(runs)
 
	def refresh(self):
		return Ensemble([run.refresh() for run in self.runs])
	
	def compute_attribution(self, ranks_to_metrics: Dict[str, List[str]]={}, instantaneous_metrics=[]):
		if self.attributions != {}:
			print("Attributions already computed, returning cached results.")
			return self.attributions
		
		for run in self.runs:
			print(f"Computing attribution for run {run.path}...")
			self.attributions[os.path.basename(os.path.dirname(run.path))] = run.compute_attribution(ranks_to_metrics, instantaneous_metrics)
		return self.attributions
 
	def compute_attribution_across_runs(self, ranks_to_metrics: Dict[str, List[str]] = {}, instantaneous_metrics = []):
		attributions = self.compute_attribution(ranks_to_metrics, instantaneous_metrics)
		if not attributions:
			return pd.DataFrame(columns=['Run', 'Node', 'Code Region', 'Metric', 'Value'])

		records = []
		for run_name, node_attribs in attributions.items():
			for node_name, df in node_attribs.items():
				if df is None or df.empty: 
					continue
				code = df['Code Region'].to_numpy()
				for metric in df.columns:
					if metric == 'Code Region': 
						continue
					vals = df[metric].to_numpy()
					# Extend in bulk (no per-iteration concatenations)
					records.extend(
						{'Run': run_name, 'Node': node_name, 'Code Region': c, 'Metric': metric, 'Value': v}
						for c, v in zip(code, vals)
					)
		return pd.DataFrame.from_records(records)

	def to_thicket(self) -> tt.Thicket:
		thickets = []
		for run in self.runs:
			name = os.path.basename(os.path.dirname(run.path))
			print(f"Creating Thicket for run {run.path} ({name})...")
			tf = run.to_thicket(trace=run.path, run=name)
			thickets.append(tf)
		if thickets:
			return tt.Thicket.concat_thickets(thickets, disable_tqdm=True)
		else:
			return tt.Thicket()

# %% [markdown]
# # Begin Analysis!
# Load in the rocHPL data

# %%
rochpl = Ensemble.from_trace_paths(
    ROCHPL_TRACES,
    HPL_NODE_RANKS
)
# Out:
# Loading run from trace path: ../frontier-results/rochpl-r8--P_1_-Q_8_-N_245760/trial_2-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/rochpl-r8--P_1_-Q_8_-N_245760/trial_2-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 17091799 in 1.90549 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 6.02221 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.20671318e+09 1.20671318e+09 1.20671319e+09 ... 1.20674941e+09
#  1.20674941e+09 1.20674941e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/rochpl-r8--P_1_-Q_8_-N_245760/trial_1-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/rochpl-r8--P_1_-Q_8_-N_245760/trial_1-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 17192386 in 1.96455 seconds
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 6.37802 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.20667644e+09 1.20667644e+09 1.20667644e+09 ... 1.20671275e+09
#  1.20671275e+09 1.20671275e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/rochpl-r8--P_1_-Q_8_-N_245760/trial_1-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/rochpl-r8--P_1_-Q_8_-N_245760/trial_1-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 17216396 in 1.89853 seconds
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 5.37418 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.89969148e+09 1.89969148e+09 1.89969148e+09 ... 1.89972948e+09
#  1.89972948e+09 1.89972948e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/rochpl-r8--P_1_-Q_8_-N_245760/trial_2-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/rochpl-r8--P_1_-Q_8_-N_245760/trial_2-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 17193066 in 1.93134 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 6.24173 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.89972970e+09 1.89972970e+09 1.89972971e+09 ... 1.89976760e+09
#  1.89976760e+09 1.89976760e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000

# %%
rochplmxp = Ensemble.from_trace_paths(
    ROCHPL_MXP_TRACES,
    HPL_NODE_RANKS
)
# Out:
# Loading run from trace path: ../frontier-results/rochplmxp-r8--P_1_-Q_8_-N_245760/trial_2-frontier09470-r8-rochplmxp--P_1_-Q_8_-N_245760/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/rochplmxp-r8--P_1_-Q_8_-N_245760/trial_2-frontier09470-r8-rochplmxp--P_1_-Q_8_-N_245760/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 3294459 in 0.365133 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 1.00303 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.89977573e+09 1.89977573e+09 1.89977573e+09 ... 1.89978320e+09
#  1.89978320e+09 1.89978320e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/rochplmxp-r8--P_1_-Q_8_-N_245760/trial_2-frontier10192-r8-rochplmxp--P_1_-Q_8_-N_245760/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/rochplmxp-r8--P_1_-Q_8_-N_245760/trial_2-frontier10192-r8-rochplmxp--P_1_-Q_8_-N_245760/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 3280670 in 0.366099 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 1.02656 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.20675744e+09 1.20675744e+09 1.20675744e+09 ... 1.20676464e+09
#  1.20676464e+09 1.20676464e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/rochplmxp-r8--P_1_-Q_8_-N_245760/trial_1-frontier09470-r8-rochplmxp--P_1_-Q_8_-N_245760/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/rochplmxp-r8--P_1_-Q_8_-N_245760/trial_1-frontier09470-r8-rochplmxp--P_1_-Q_8_-N_245760/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 3322960 in 0.375649 seconds
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 0.91811 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.89976788e+09 1.89976788e+09 1.89976788e+09 ... 1.89977556e+09
#  1.89977556e+09 1.89977556e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/rochplmxp-r8--P_1_-Q_8_-N_245760/trial_1-frontier10192-r8-rochplmxp--P_1_-Q_8_-N_245760/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/rochplmxp-r8--P_1_-Q_8_-N_245760/trial_1-frontier10192-r8-rochplmxp--P_1_-Q_8_-N_245760/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 3308962 in 0.3642 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 1.0412 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.20674992e+09 1.20674992e+09 1.20674992e+09 ... 1.20675728e+09
#  1.20675728e+09 1.20675729e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000

# %%
hpg = Ensemble.from_trace_paths(
    HPG_TRACES,
    HPG_NODE_RANKS,
)
# Out:
# Loading run from trace path: ../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_ref/trial_1-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_ref/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_ref/trial_1-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_ref/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 37767828 in 4.3155 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Total time: 15.6007 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.89979844e+09 1.89979844e+09 1.89979844e+09 ... 1.89980894e+09
#  1.89980894e+09 1.89980894e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_ref/trial_1-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_ref/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_ref/trial_1-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_ref/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 37750193 in 4.41358 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 14.4153 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.20677927e+09 1.20677927e+09 1.20677927e+09 ... 1.20678954e+09
#  1.20678954e+09 1.20678954e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_ref/trial_2-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_ref/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_ref/trial_2-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_ref/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 37744269 in 4.34666 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 15.1694 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.89980927e+09 1.89980927e+09 1.89980927e+09 ... 1.89981976e+09
#  1.89981976e+09 1.89981976e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_ref/trial_2-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_ref/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_ref/trial_2-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_ref/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 37748166 in 4.50922 seconds
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Total time: 15.5622 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.20678975e+09 1.20678975e+09 1.20678975e+09 ... 1.20680004e+09
#  1.20680004e+09 1.20680004e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000

# %%
hpgmxp = Ensemble.from_trace_paths(
    HPG_MXP_TRACES,
    HPG_NODE_RANKS,
)
# Out:
# Loading run from trace path: ../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_mxp/trial_1-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_mxp/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_mxp/trial_1-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_mxp/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 34223352 in 4.04608 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 13.0737 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.20676484e+09 1.20676484e+09 1.20676484e+09 ... 1.20677189e+09
#  1.20677189e+09 1.20677189e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_mxp/trial_1-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_mxp/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_mxp/trial_1-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_mxp/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 34246253 in 4.05943 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 13.0579 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.89978347e+09 1.89978347e+09 1.89978347e+09 ... 1.89979081e+09
#  1.89979081e+09 1.89979081e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_mxp/trial_2-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_mxp/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_mxp/trial_2-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_mxp/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 34218705 in 3.88017 seconds
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Total time: 13.3461 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.20677210e+09 1.20677210e+09 1.20677210e+09 ... 1.20677909e+09
#  1.20677909e+09 1.20677909e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000
# Loading run from trace path: ../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_mxp/trial_2-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_mxp/traces.otf2
# Tracking metrics: ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6', 'A2coretemp:::craypm:accel0_energy', 'A2coretemp:::craypm:accel1_energy', 'A2coretemp:::craypm:accel2_energy', 'A2coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power', 'A3coretemp:::craypm:accel0_energy', 'A3coretemp:::craypm:accel1_energy', 'A3coretemp:::craypm:accel2_energy', 'A3coretemp:::craypm:accel3_energy', 'A2coretemp:::craypm:accel0_energy_timestamp', 'A2coretemp:::craypm:accel1_energy_timestamp', 'A2coretemp:::craypm:accel2_energy_timestamp', 'A2coretemp:::craypm:accel3_energy_timestamp', 'A2coretemp:::craypm:freshness']
# Running command: ./trace_to_csv_parallel --trace=../frontier-results/xhpgmp-r8-128_128_128_--run_type=standalone_mxp/trial_2-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_mxp/traces.otf2 --metrics="A2rocm_smi:::energy_count:device=0,A2rocm_smi:::energy_count:device=2,A2rocm_smi:::energy_count:device=4,A2rocm_smi:::energy_count:device=6,A2coretemp:::craypm:accel0_energy,A2coretemp:::craypm:accel1_energy,A2coretemp:::craypm:accel2_energy,A2coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_power,A2coretemp:::craypm:accel1_power,A2coretemp:::craypm:accel2_power,A2coretemp:::craypm:accel3_power,A3coretemp:::craypm:accel0_energy,A3coretemp:::craypm:accel1_energy,A3coretemp:::craypm:accel2_energy,A3coretemp:::craypm:accel3_energy,A2coretemp:::craypm:accel0_energy_timestamp,A2coretemp:::craypm:accel1_energy_timestamp,A2coretemp:::craypm:accel2_energy_timestamp,A2coretemp:::craypm:accel3_energy_timestamp,A2coretemp:::craypm:freshness"
# Number of locations: 45
# Number of readers: 12
# Event Summary: total events read across readers = 34248349 in 3.90773 seconds
# Writing: ./MPI Rank 3_Master_thread_callgraph.csv
# Writing: ./MPI Rank 5_Master_thread_callgraph.csv
# Writing: ./MPI Rank 1_Master_thread_callgraph.csv
# Writing: ./MPI Rank 4_Master_thread_callgraph.csv
# Writing: ./MPI Rank 2_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_Master_thread_callgraph.csv
# Writing: ./MPI Rank 0_UnknownLocation_callgraph.csv
# Writing: ./MPI Rank 6_Master_thread_callgraph.csv
# Writing: ./MPI Rank 7_metrics.csv
# Writing: ./MPI Rank 6_metrics.csv
# Writing: ./MPI Rank 4_metrics.csv
# Writing: ./MPI Rank 3_metrics.csv
# Writing: ./MPI Rank 2_metrics.csv
# Writing: ./MPI Rank 5_metrics.csv
# Writing: ./MPI Rank 0_metrics.csv
# Writing: ./MPI Rank 1_metrics.csv
# Total time: 13.5158 seconds
# /var/folders/3h/cbgps36j7q58_ghglykw4ggw0000gn/T/ipykernel_46810/65557790.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.89979100e+09 1.89979100e+09 1.89979100e+09 ... 1.89979826e+09
#  1.89979826e+09 1.89979826e+09]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Metric Name'] == metric_name, 'Value'] /= 1_000_000

# %%
def calculate_percent_time_above_tdp(ensemble: Ensemble, tdp_threshold: float = 560.0, metric_name: str = 'A2coretemp:::craypm:accel0_power', differentiate_rocm: bool = True):
    results = {}
    for run in ensemble.runs:
        run_name = os.path.basename(os.path.dirname(run.path))
        node_name = re.findall(r'frontier\d+', run.path.split('/')[-2])[0]
        if node_name not in results:
            results[node_name] = []
        for node in run.nodes:
            metric_df = node.get_metric_samples(metric_name)
            if metric_df.empty:
                print(f"No data for metric {metric_name} on node {node.name} in run {run_name}.")
                results[run_name].append(None)
                continue
            f_power = sampled_to_continuous(metric_df)
            if differentiate_rocm and 'rocm' in metric_name.lower():
                f_power = numerical_derivative(f_power)
            
            total_time = 0.0
            time_above_tdp = 0.0

            times = metric_df[metric_df['Metric Name'] == metric_name]['Time'].astype(float).to_numpy()
            times_sorted = np.sort(times)
            
            
            power_values = f_power(times_sorted)
            # Count how many are above TDP
            above_tdp = power_values > tdp_threshold
            # Calculate how many total are above TDP vs total samples
            total_above_tdp = np.sum(above_tdp)
            total_samples = len(times_sorted)
            percent_above_tdp = (total_above_tdp / total_samples) * 100.0 if total_samples > 0 else 0.0
            results[node_name].append(percent_above_tdp)
    return results

calculate_percent_time_above_tdp(rochpl, tdp_threshold=560.0, metric_name='A2rocm_smi:::energy_count:device=0')
# Out:
# {'frontier10192': [41.57160407160407, 41.24706400469759],
#  'frontier09470': [39.40890413540921, 41.04711222413523]}

# %%
def visualize_percent_time_above_tdp_boxplot(
    ensembles: Dict[str, Ensemble], tdp_threshold=560.0,
    metric_name='A2coretemp:::craypm:accel0_power',
    differentiate_rocm=True):
    
    all_data = []
    for ensemble_name, ensemble in ensembles.items():
        results = calculate_percent_time_above_tdp(ensemble, tdp_threshold, metric_name, differentiate_rocm)
        for node, values in results.items():
            for v in values:
                all_data.append({'Ensemble': ensemble_name, 'Node': node, 'Value': v})
    
    df = pd.DataFrame(all_data)
    df = df.sort_values('Node')

    plt.figure(figsize=(12, 6))
    sns.violinplot(data=df, x='Node', y='Value', hue='Ensemble')
    plt.xticks(rotation=45)
    plt.ylabel('Percent Time Above TDP (%)')
    plt.title(f'Percent Time Above {tdp_threshold}W')
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

visualize_percent_time_above_tdp_boxplot({'rocHPL': rochpl, 'rocHPL-MxP': rochplmxp, 'HPG': hpg, 'HPG-MxP': hpgmxp}, 560.0, metric_name='A2rocm_smi:::energy_count:device=0')

# %%
def visualize_percent_time_above_tdp_piechart(
    ensembles: Dict[str, Ensemble], tdp_threshold=560.0,
    metric_name='A2coretemp:::craypm:accel0_power',
    differentiate_rocm=True):
    
    # Show a single pie chart for each 

    '''
    # For each ensemble, calculate average percent time above TDP across all nodes and runs
    for ensemble_name, ensemble in ensembles.items():
        avg_data = {}
        plt.figure(figsize=(8, 6))
        results = calculate_percent_time_above_tdp(ensemble, tdp_threshold, metric_name, differentiate_rocm)
        all_executions = []
        for node, values in results.items():
            # Remove None values
            values = [v for v in values if v is not None]
            if len(values) == 0:
                continue
            all_executions.extend(values)
        percent_above = np.mean(all_executions)
        percent_below = 100.0 - percent_above
        plt.pie(
            [percent_above, percent_below],
            autopct=lambda x: f'{x:.1f}%' if x > 0 else '',
            startangle=90,
            labels=[f'Above {tdp_threshold}W' if percent_above > 0 else '', f'Below {tdp_threshold}W' if percent_below > 0 else ''],
            colors=['#ff9999','#66b3ff']
        )
        plt.title(f'Distribution of Time Above {tdp_threshold}W for {ensemble_name}')
        # plt.axis('equal')
        # plt.tight_layout()
        plt.legend()
        plt.show()
    '''
    # Show 4 bar charts instead in a single figure
    avg_data = {}
    for ensemble_name, ensemble in ensembles.items():
        results = calculate_percent_time_above_tdp(ensemble, tdp_threshold, metric_name, differentiate_rocm)
        all_executions = []
        for node, values in results.items():
            # Remove None values
            values = [v for v in values if v is not None]
            if len(values) == 0:
                continue
            all_executions.extend(values)
        percent_above = np.mean(all_executions)
        avg_data[ensemble_name] = percent_above
    plt.figure(figsize=(10, 6))
    bc = plt.bar(avg_data.keys(), avg_data.values(), color=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99'], label=list(avg_data.keys()))
    plt.bar_label(bc, fmt='%.1f%%', padding=3)
    plt.ylabel('Average Percent Time Above TDP Across All GPUs (%)')
    plt.title(f'Average Percent Time Above {tdp_threshold}W Across Ensembles ({metric_name})')
    plt.ylim(0, 100)
    plt.grid(axis='y')
    plt.legend()
    plt.tight_layout()
    plt.show()

visualize_percent_time_above_tdp_piechart({'rocHPL (Full Precision)': rochpl, 'rocHPL-MxP (Mixed Precision)': rochplmxp, 'HPG-MxP (Full Precision)': hpg, 'HPG-MxP (Mixed Precision)': hpgmxp}, 560 * 0.95, metric_name='A2rocm_smi:::energy_count:device=0')
visualize_percent_time_above_tdp_piechart({'rocHPL (Full Precision)': rochpl, 'rocHPL-MxP (Mixed Precision)': rochplmxp, 'HPG-MxP (Full Precision)': hpg, 'HPG-MxP (Mixed Precision)': hpgmxp}, 560, metric_name='A2rocm_smi:::energy_count:device=0')
visualize_percent_time_above_tdp_piechart({'rocHPL (Full Precision)': rochpl, 'rocHPL-MxP (Mixed Precision)': rochplmxp, 'HPG-MxP (Full Precision)': hpg, 'HPG-MxP (Mixed Precision)': hpgmxp}, 560 * 1.05, metric_name='A2rocm_smi:::energy_count:device=0')

# %%
visualize_percent_time_above_tdp_piechart({'rocHPL (Full Precision)': rochpl, 'rocHPL-MxP (Mixed Precision)': rochplmxp, 'HPG-MxP (Full Precision)': hpg, 'HPG-MxP (Mixed Precision)': hpgmxp}, 560 * 0.95, metric_name='A2coretemp:::craypm:accel0_power')
visualize_percent_time_above_tdp_piechart({'rocHPL (Full Precision)': rochpl, 'rocHPL-MxP (Mixed Precision)': rochplmxp, 'HPG-MxP (Full Precision)': hpg, 'HPG-MxP (Mixed Precision)': hpgmxp}, 560, metric_name='A2coretemp:::craypm:accel0_power')
visualize_percent_time_above_tdp_piechart({'rocHPL (Full Precision)': rochpl, 'rocHPL-MxP (Mixed Precision)': rochplmxp, 'HPG-MxP (Full Precision)': hpg, 'HPG-MxP (Mixed Precision)': hpgmxp}, 560 * 1.05, metric_name='A2coretemp:::craypm:accel0_power')

# %%
def time_over_tdp(ensemble: Ensemble, benchmark_name: str=''):
    rocm_metric_name = 'A2rocm_smi:::energy_count:device=0'
    cray_metric_name = 'A2coretemp:::craypm:accel0_power'
    print(ensemble)
    cray_95_percents = []
    rocm_95_percents = []
    cray_100_percents = []
    rocm_100_percents = []
    for rocm_metric_name in ['A2rocm_smi:::energy_count:device=0', 'A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6']:
        for cray_metric_name in ['A2coretemp:::craypm:accel0_power', 'A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power']:
    # for rocm_metric_name in ['A2rocm_smi:::energy_count:device=2', 'A2rocm_smi:::energy_count:device=4', 'A2rocm_smi:::energy_count:device=6']:
    #     for cray_metric_name in ['A2coretemp:::craypm:accel1_power', 'A2coretemp:::craypm:accel2_power', 'A2coretemp:::craypm:accel3_power']:
            for run in ensemble.runs:
                for node in run.nodes:
                    df = node.metrics
                    df_rocm = df[df['Metric Name'] == rocm_metric_name].sort_values('Time')

                    # Collect Cray metric deltas
                    df_cray = df[df['Metric Name'] == cray_metric_name].sort_values('Time')
                    
                    GPU_TDP = 560.0 # Watts, adjust as needed
                    
                    # Find the percent time spent above 95% of TDP
                    cray_pm_above_95_count = np.sum(df_cray['Value'] > 0.95 * GPU_TDP)
                    cray_pm_total_count = df_cray.shape[0]
                    if cray_pm_total_count > 0:
                        cray_pm_above_95_percent = (cray_pm_above_95_count / cray_pm_total_count) * 100
                    else:
                        cray_pm_above_95_percent = 0.0
                        
                    # Now above 100%
                    cray_pm_above_100_count = np.sum(df_cray['Value'] > GPU_TDP)
                    if cray_pm_total_count > 0:
                        cray_pm_above_100_percent = (cray_pm_above_100_count / cray_pm_total_count) * 100
                    else:
                        cray_pm_above_100_percent = 0.0
                    
                    # Now rocm
                    # First, create a "power" metric by differentiating energy over time
                    # Filter all repeated energy values (keep only changes)
                    df_rocm = df_rocm[df_rocm['Value'].diff() != 0]
                    df_rocm['Power'] = df_rocm['Value'].diff() / df_rocm['Time'].diff()
                    print(df_rocm)
                    rocm_above_95_count = np.sum(df_rocm['Power'] > 0.95 * GPU_TDP)
                    rocm_total_count = df_rocm.shape[0]
                    if rocm_total_count > 0:
                        rocm_above_95_percent = (rocm_above_95_count / rocm_total_count) * 100
                    else:
                        rocm_above_95_percent = 0.0
                    rocm_above_100_count = np.sum(df_rocm['Power'] > GPU_TDP)
                    if rocm_total_count > 0:
                        rocm_above_100_percent = (rocm_above_100_count / rocm_total_count) * 100
                    else:
                        rocm_above_100_percent = 0.0
                        
                    # Show a graph of the power over time
                    # plt.figure(figsize=(10, 5))
                    # plt.plot(df_rocm['Time'], df_rocm['Power'], label='ROCm Power (W)', color='blue', alpha=0.7)
                    # print('Cray:', df_cray)
                    # plt.plot(df_cray['Time'], df_cray['Value'], label='CrayPM Power (W)', color='red')
                    # plt.axhline(0.95 * GPU_TDP, color='orange', linestyle='--', label='95% TDP')
                    # plt.axhline(GPU_TDP, color='red', linestyle='--', label='100% TDP')
                    # plt.xlabel('Time (s)')
                    # plt.ylabel('Power (W)')
                    # plt.title(f'ROCm Power over Time for Node {node.name} in Run {os.path.basename(os.path.dirname(run.path))}')
                    # plt.legend()
                    # plt.grid()
                    # plt.show()
                        
                    print(f"Run: {os.path.basename(os.path.dirname(run.path))}, Node: {node.name}")
                    print(f"  CrayPM > 95% TDP: {cray_pm_above_95_percent:.2f}% ({cray_pm_above_95_count}/{cray_pm_total_count})")
                    print(f"  CrayPM > 100% TDP: {cray_pm_above_100_percent:.2f}% ({cray_pm_above_100_count}/{cray_pm_total_count})")
                    print(f"  ROCm > 95% TDP: {rocm_above_95_percent:.2f}% ({rocm_above_95_count}/{rocm_total_count})")
                    print(f"  ROCm > 100% TDP: {rocm_above_100_percent:.2f}% ({rocm_above_100_count}/{rocm_total_count})")
                    cray_95_percents.append(cray_pm_above_95_percent)
                    rocm_95_percents.append(rocm_above_95_percent)
                    cray_100_percents.append(cray_pm_above_100_percent)
                    rocm_100_percents.append(rocm_above_100_percent)
                
            
            
    # Show a distribution of the time spent over TDP across all nodes in the run
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.hist(cray_95_percents, bins=10, alpha=0.7, label='CrayPM > 95% TDP', color='red')
    plt.hist(rocm_95_percents, bins=10, alpha=0.7, label='ROCm > 95% TDP', color='blue')
    plt.xlabel('Percentage of Application Runtime (%)')
    plt.ylabel('Number of GPUs')
    if benchmark_name:
        plt.title(f'Distribution of Time Spent Above 95% TDP ({benchmark_name})')
    else:
        plt.title('Distribution of Time Spent Above 95% TDP')
    plt.legend()
    plt.grid()
    plt.subplot(1, 2, 2)
    plt.hist(cray_100_percents, bins=10, alpha=0.7, label='CrayPM > 100% TDP', color='red')
    plt.hist(rocm_100_percents, bins=10, alpha=0.7, label='ROCm > 100% TDP', color='blue')
    plt.xlabel('Percentage of Application Runtime (%)')
    plt.ylabel('Number of GPUs')
    if benchmark_name:
        plt.title(f'Distribution of Time Spent Above 100% TDP ({benchmark_name})')
    else:
        plt.title('Distribution of Time Spent Above 100% TDP')
    plt.show() 

time_over_tdp(rochpl, "rocHPL")
time_over_tdp(rochplmxp, "rocHPL-MxP")
time_over_tdp(hpg, "HPG")
time_over_tdp(hpgmxp, "HPG-MxP")
# Out:
# <__main__.Ensemble object at 0x11d64b8c0>
#             Group                         Metric Name       Time  \
# 68376  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.206994
# 68377  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.210992
# 68378  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.213843
# 68379  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.231915
# 68380  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.234055
# ...           ...                                 ...        ...
# 91163  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.801784
# 91164  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.806187
# 91165  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.811535
# 91166  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.814768
# 91167  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.817482
#
#               Value       Power
# 68376  1.249893e+09         NaN
# 68377  1.249893e+09   70.357837
# 68378  1.249893e+09  596.271621
# 68379  1.249893e+09   15.783065
# 68380  1.249893e+09   88.620573
# ...             ...         ...
# 91163  1.249930e+09  107.149718
# 91164  1.249930e+09  164.471286
# 91165  1.249930e+09  133.355722
# 91166  1.249930e+09  112.932714
# 91167  1.249930e+09  117.107200
#
# [22792 rows x 5 columns]
# Run: trial_2-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 65.71% (433/659)
#   CrayPM > 100% TDP: 60.39% (398/659)
#   ROCm > 95% TDP: 32.70% (7452/22792)
#   ROCm > 100% TDP: 27.89% (6356/22792)
#              Group                         Metric Name       Time  \
# 81744   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.390190
# 81745   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.393194
# 81746   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.397890
# 81747   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.400096
# 81748   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.407820
# ...            ...                                 ...        ...
# 108987  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.162025
# 108988  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.164173
# 108989  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.167371
# 108990  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.169859
# 108991  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.172087
#
#                Value       Power
# 81744   1.249856e+09         NaN
# 81745   1.249856e+09   91.152977
# 81746   1.249856e+09   77.621266
# 81747   1.249856e+09   82.294823
# 81748   1.249856e+09   94.303737
# ...              ...         ...
# 108987  1.249893e+09  131.440818
# 108988  1.249893e+09  200.300538
# 108989  1.249893e+09  106.147583
# 108990  1.249893e+09   84.441239
# 108991  1.249893e+09   94.499089
#
# [27248 rows x 5 columns]
# Run: trial_1-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 65.55% (432/659)
#   CrayPM > 100% TDP: 62.67% (413/659)
#   ROCm > 95% TDP: 31.64% (8621/27248)
#   ROCm > 100% TDP: 27.29% (7436/27248)
#              Group                         Metric Name       Time  \
# 79581   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.700271
# 79582   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.702886
# 79583   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.705156
# 79584   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.707767
# 79585   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.710161
# ...            ...                                 ...        ...
# 106103  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.855052
# 106104  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.858306
# 106105  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.861522
# 106106  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.863961
# 106107  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.866881
#
#                Value       Power
# 79581   1.948597e+09         NaN
# 79582   1.948597e+09   69.306704
# 79583   1.948597e+09  120.071883
# 79584   1.948597e+09   70.296641
# 79585   1.948597e+09  114.841518
# ...              ...         ...
# 106103  1.948636e+09  162.899839
# 106104  1.948636e+09  131.182173
# 106105  1.948636e+09  112.924433
# 106106  1.948636e+09  129.822409
# 106107  1.948636e+09  109.089196
#
# [26527 rows x 5 columns]
# Run: trial_1-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 64.16% (426/664)
#   CrayPM > 100% TDP: 47.74% (317/664)
#   ROCm > 95% TDP: 33.92% (8999/26527)
#   ROCm > 100% TDP: 29.12% (7725/26527)
#              Group                         Metric Name       Time  \
# 76668   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.207241
# 76669   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.211228
# 76670   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.214094
# 76671   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.231073
# 76672   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.234275
# ...            ...                                 ...        ...
# 102219  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.636599
# 102220  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.639824
# 102221  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.643054
# 102222  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.646597
# 102223  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.649092
#
#                Value       Power
# 76668   1.948636e+09         NaN
# 76669   1.948636e+09  103.653217
# 76670   1.948636e+09   72.223518
# 76671   1.948636e+09  102.601007
# 76672   1.948636e+09  124.662610
# ...              ...         ...
# 102219  1.948674e+09  126.679803
# 102220  1.948674e+09  133.298955
# 102221  1.948674e+09  177.952980
# 102222  1.948674e+09   91.272737
# 102223  1.948674e+09  128.417181
#
# [25556 rows x 5 columns]
# Run: trial_2-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 62.92% (414/658)
#   CrayPM > 100% TDP: 49.39% (325/658)
#   ROCm > 95% TDP: 33.03% (8441/25556)
#   ROCm > 100% TDP: 28.90% (7385/25556)
#             Group                         Metric Name       Time  \
# 68376  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.206994
# 68377  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.210992
# 68378  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.213843
# 68379  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.231915
# 68380  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.234055
# ...           ...                                 ...        ...
# 91163  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.801784
# 91164  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.806187
# 91165  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.811535
# 91166  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.814768
# 91167  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.817482
#
#               Value       Power
# 68376  1.249893e+09         NaN
# 68377  1.249893e+09   70.357837
# 68378  1.249893e+09  596.271621
# 68379  1.249893e+09   15.783065
# 68380  1.249893e+09   88.620573
# ...             ...         ...
# 91163  1.249930e+09  107.149718
# 91164  1.249930e+09  164.471286
# 91165  1.249930e+09  133.355722
# 91166  1.249930e+09  112.932714
# 91167  1.249930e+09  117.107200
#
# [22792 rows x 5 columns]
# Run: trial_2-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 67.79% (442/652)
#   CrayPM > 100% TDP: 66.56% (434/652)
#   ROCm > 95% TDP: 32.70% (7452/22792)
#   ROCm > 100% TDP: 27.89% (6356/22792)
#              Group                         Metric Name       Time  \
# 81744   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.390190
# 81745   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.393194
# 81746   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.397890
# 81747   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.400096
# 81748   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.407820
# ...            ...                                 ...        ...
# 108987  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.162025
# 108988  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.164173
# 108989  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.167371
# 108990  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.169859
# 108991  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.172087
#
#                Value       Power
# 81744   1.249856e+09         NaN
# 81745   1.249856e+09   91.152977
# 81746   1.249856e+09   77.621266
# 81747   1.249856e+09   82.294823
# 81748   1.249856e+09   94.303737
# ...              ...         ...
# 108987  1.249893e+09  131.440818
# 108988  1.249893e+09  200.300538
# 108989  1.249893e+09  106.147583
# 108990  1.249893e+09   84.441239
# 108991  1.249893e+09   94.499089
#
# [27248 rows x 5 columns]
# Run: trial_1-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 69.04% (455/659)
#   CrayPM > 100% TDP: 67.37% (444/659)
#   ROCm > 95% TDP: 31.64% (8621/27248)
#   ROCm > 100% TDP: 27.29% (7436/27248)
#              Group                         Metric Name       Time  \
# 79581   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.700271
# 79582   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.702886
# 79583   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.705156
# 79584   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.707767
# 79585   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.710161
# ...            ...                                 ...        ...
# 106103  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.855052
# 106104  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.858306
# 106105  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.861522
# 106106  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.863961
# 106107  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.866881
#
#                Value       Power
# 79581   1.948597e+09         NaN
# 79582   1.948597e+09   69.306704
# 79583   1.948597e+09  120.071883
# 79584   1.948597e+09   70.296641
# 79585   1.948597e+09  114.841518
# ...              ...         ...
# 106103  1.948636e+09  162.899839
# 106104  1.948636e+09  131.182173
# 106105  1.948636e+09  112.924433
# 106106  1.948636e+09  129.822409
# 106107  1.948636e+09  109.089196
#
# [26527 rows x 5 columns]
# Run: trial_1-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 65.51% (435/664)
#   CrayPM > 100% TDP: 18.37% (122/664)
#   ROCm > 95% TDP: 33.92% (8999/26527)
#   ROCm > 100% TDP: 29.12% (7725/26527)
#              Group                         Metric Name       Time  \
# 76668   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.207241
# 76669   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.211228
# 76670   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.214094
# 76671   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.231073
# 76672   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.234275
# ...            ...                                 ...        ...
# 102219  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.636599
# 102220  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.639824
# 102221  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.643054
# 102222  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.646597
# 102223  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.649092
#
#                Value       Power
# 76668   1.948636e+09         NaN
# 76669   1.948636e+09  103.653217
# 76670   1.948636e+09   72.223518
# 76671   1.948636e+09  102.601007
# 76672   1.948636e+09  124.662610
# ...              ...         ...
# 102219  1.948674e+09  126.679803
# 102220  1.948674e+09  133.298955
# 102221  1.948674e+09  177.952980
# 102222  1.948674e+09   91.272737
# 102223  1.948674e+09  128.417181
#
# [25556 rows x 5 columns]
# Run: trial_2-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 66.11% (433/655)
#   CrayPM > 100% TDP: 22.14% (145/655)
#   ROCm > 95% TDP: 33.03% (8441/25556)
#   ROCm > 100% TDP: 28.90% (7385/25556)
#             Group                         Metric Name       Time  \
# 68376  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.206994
# 68377  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.210992
# 68378  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.213843
# 68379  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.231915
# 68380  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.234055
# ...           ...                                 ...        ...
# 91163  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.801784
# 91164  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.806187
# 91165  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.811535
# 91166  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.814768
# 91167  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.817482
#
#               Value       Power
# 68376  1.249893e+09         NaN
# 68377  1.249893e+09   70.357837
# 68378  1.249893e+09  596.271621
# 68379  1.249893e+09   15.783065
# 68380  1.249893e+09   88.620573
# ...             ...         ...
# 91163  1.249930e+09  107.149718
# 91164  1.249930e+09  164.471286
# 91165  1.249930e+09  133.355722
# 91166  1.249930e+09  112.932714
# 91167  1.249930e+09  117.107200
#
# [22792 rows x 5 columns]
# Run: trial_2-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 66.72% (439/658)
#   CrayPM > 100% TDP: 62.16% (409/658)
#   ROCm > 95% TDP: 32.70% (7452/22792)
#   ROCm > 100% TDP: 27.89% (6356/22792)
#              Group                         Metric Name       Time  \
# 81744   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.390190
# 81745   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.393194
# 81746   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.397890
# 81747   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.400096
# 81748   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.407820
# ...            ...                                 ...        ...
# 108987  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.162025
# 108988  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.164173
# 108989  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.167371
# 108990  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.169859
# 108991  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.172087
#
#                Value       Power
# 81744   1.249856e+09         NaN
# 81745   1.249856e+09   91.152977
# 81746   1.249856e+09   77.621266
# 81747   1.249856e+09   82.294823
# 81748   1.249856e+09   94.303737
# ...              ...         ...
# 108987  1.249893e+09  131.440818
# 108988  1.249893e+09  200.300538
# 108989  1.249893e+09  106.147583
# 108990  1.249893e+09   84.441239
# 108991  1.249893e+09   94.499089
#
# [27248 rows x 5 columns]
# Run: trial_1-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 66.17% (440/665)
#   CrayPM > 100% TDP: 63.01% (419/665)
#   ROCm > 95% TDP: 31.64% (8621/27248)
#   ROCm > 100% TDP: 27.29% (7436/27248)
#              Group                         Metric Name       Time  \
# 79581   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.700271
# 79582   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.702886
# 79583   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.705156
# 79584   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.707767
# 79585   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.710161
# ...            ...                                 ...        ...
# 106103  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.855052
# 106104  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.858306
# 106105  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.861522
# 106106  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.863961
# 106107  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.866881
#
#                Value       Power
# 79581   1.948597e+09         NaN
# 79582   1.948597e+09   69.306704
# 79583   1.948597e+09  120.071883
# 79584   1.948597e+09   70.296641
# 79585   1.948597e+09  114.841518
# ...              ...         ...
# 106103  1.948636e+09  162.899839
# 106104  1.948636e+09  131.182173
# 106105  1.948636e+09  112.924433
# 106106  1.948636e+09  129.822409
# 106107  1.948636e+09  109.089196
#
# [26527 rows x 5 columns]
# Run: trial_1-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 64.42% (431/669)
#   CrayPM > 100% TDP: 23.77% (159/669)
#   ROCm > 95% TDP: 33.92% (8999/26527)
#   ROCm > 100% TDP: 29.12% (7725/26527)
#              Group                         Metric Name       Time  \
# 76668   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.207241
# 76669   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.211228
# 76670   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.214094
# 76671   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.231073
# 76672   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.234275
# ...            ...                                 ...        ...
# 102219  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.636599
# 102220  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.639824
# 102221  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.643054
# 102222  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.646597
# 102223  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.649092
#
#                Value       Power
# 76668   1.948636e+09         NaN
# 76669   1.948636e+09  103.653217
# 76670   1.948636e+09   72.223518
# 76671   1.948636e+09  102.601007
# 76672   1.948636e+09  124.662610
# ...              ...         ...
# 102219  1.948674e+09  126.679803
# 102220  1.948674e+09  133.298955
# 102221  1.948674e+09  177.952980
# 102222  1.948674e+09   91.272737
# 102223  1.948674e+09  128.417181
#
# [25556 rows x 5 columns]
# Run: trial_2-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 66.56% (436/655)
#   CrayPM > 100% TDP: 24.12% (158/655)
#   ROCm > 95% TDP: 33.03% (8441/25556)
#   ROCm > 100% TDP: 28.90% (7385/25556)
#             Group                         Metric Name       Time  \
# 68376  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.206994
# 68377  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.210992
# 68378  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.213843
# 68379  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.231915
# 68380  MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.234055
# ...           ...                                 ...        ...
# 91163  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.801784
# 91164  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.806187
# 91165  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.811535
# 91166  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.814768
# 91167  MPI Rank 0  A2rocm_smi:::energy_count:device=0  82.817482
#
#               Value       Power
# 68376  1.249893e+09         NaN
# 68377  1.249893e+09   70.357837
# 68378  1.249893e+09  596.271621
# 68379  1.249893e+09   15.783065
# 68380  1.249893e+09   88.620573
# ...             ...         ...
# 91163  1.249930e+09  107.149718
# 91164  1.249930e+09  164.471286
# 91165  1.249930e+09  133.355722
# 91166  1.249930e+09  112.932714
# 91167  1.249930e+09  117.107200
#
# [22792 rows x 5 columns]
# Run: trial_2-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 67.53% (445/659)
#   CrayPM > 100% TDP: 64.49% (425/659)
#   ROCm > 95% TDP: 32.70% (7452/22792)
#   ROCm > 100% TDP: 27.89% (6356/22792)
#              Group                         Metric Name       Time  \
# 81744   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.390190
# 81745   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.393194
# 81746   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.397890
# 81747   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.400096
# 81748   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.407820
# ...            ...                                 ...        ...
# 108987  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.162025
# 108988  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.164173
# 108989  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.167371
# 108990  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.169859
# 108991  MPI Rank 0  A2rocm_smi:::energy_count:device=0  84.172087
#
#                Value       Power
# 81744   1.249856e+09         NaN
# 81745   1.249856e+09   91.152977
# 81746   1.249856e+09   77.621266
# 81747   1.249856e+09   82.294823
# 81748   1.249856e+09   94.303737
# ...              ...         ...
# 108987  1.249893e+09  131.440818
# 108988  1.249893e+09  200.300538
# 108989  1.249893e+09  106.147583
# 108990  1.249893e+09   84.441239
# 108991  1.249893e+09   94.499089
#
# [27248 rows x 5 columns]
# Run: trial_1-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 63.71% (416/653)
#   CrayPM > 100% TDP: 60.95% (398/653)
#   ROCm > 95% TDP: 31.64% (8621/27248)
#   ROCm > 100% TDP: 27.29% (7436/27248)
#              Group                         Metric Name       Time  \
# 79581   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.700271
# 79582   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.702886
# 79583   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.705156
# 79584   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.707767
# 79585   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.710161
# ...            ...                                 ...        ...
# 106103  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.855052
# 106104  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.858306
# 106105  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.861522
# 106106  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.863961
# 106107  MPI Rank 0  A2rocm_smi:::energy_count:device=0  87.866881
#
#                Value       Power
# 79581   1.948597e+09         NaN
# 79582   1.948597e+09   69.306704
# 79583   1.948597e+09  120.071883
# 79584   1.948597e+09   70.296641
# 79585   1.948597e+09  114.841518
# ...              ...         ...
# 106103  1.948636e+09  162.899839
# 106104  1.948636e+09  131.182173
# 106105  1.948636e+09  112.924433
# 106106  1.948636e+09  129.822409
# 106107  1.948636e+09  109.089196
#
# [26527 rows x 5 columns]
# Run: trial_1-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 66.03% (451/683)
#   CrayPM > 100% TDP: 53.73% (367/683)
#   ROCm > 95% TDP: 33.92% (8999/26527)
#   ROCm > 100% TDP: 29.12% (7725/26527)
#              Group                         Metric Name       Time  \
# 76668   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.207241
# 76669   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.211228
# 76670   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.214094
# 76671   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.231073
# 76672   MPI Rank 0  A2rocm_smi:::energy_count:device=0   0.234275
# ...            ...                                 ...        ...
# 102219  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.636599
# 102220  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.639824
# 102221  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.643054
# 102222  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.646597
# 102223  MPI Rank 0  A2rocm_smi:::energy_count:device=0  85.649092
#
#                Value       Power
# 76668   1.948636e+09         NaN
# 76669   1.948636e+09  103.653217
# 76670   1.948636e+09   72.223518
# 76671   1.948636e+09  102.601007
# 76672   1.948636e+09  124.662610
# ...              ...         ...
# 102219  1.948674e+09  126.679803
# 102220  1.948674e+09  133.298955
# 102221  1.948674e+09  177.952980
# 102222  1.948674e+09   91.272737
# 102223  1.948674e+09  128.417181
#
# [25556 rows x 5 columns]
# Run: trial_2-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 63.78% (435/682)
#   CrayPM > 100% TDP: 52.79% (360/682)
#   ROCm > 95% TDP: 33.03% (8441/25556)
#   ROCm > 100% TDP: 28.90% (7385/25556)
#             Group                         Metric Name       Time  \
# 45584  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.206994
# 45585  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.210992
# 45586  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.213843
# 45587  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.231915
# 45588  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.234055
# ...           ...                                 ...        ...
# 68371  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.801784
# 68372  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.806187
# 68373  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.811535
# 68374  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.814768
# 68375  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.817482
#
#               Value       Power
# 45584  1.200162e+09         NaN
# 45585  1.200162e+09   87.899428
# 45586  1.200162e+09  557.282753
# 45587  1.200162e+09   14.609680
# 45588  1.200162e+09   82.115419
# ...             ...         ...
# 68371  1.200199e+09  111.329810
# 68372  1.200199e+09  148.198094
# 68373  1.200199e+09  117.699578
# 68374  1.200199e+09  115.824856
# 68375  1.200199e+09  110.090666
#
# [22792 rows x 5 columns]
# Run: trial_2-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 65.71% (433/659)
#   CrayPM > 100% TDP: 60.39% (398/659)
#   ROCm > 95% TDP: 34.26% (7808/22792)
#   ROCm > 100% TDP: 27.00% (6154/22792)
#             Group                         Metric Name       Time  \
# 54496  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.390190
# 54497  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.393194
# 54498  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.397890
# 54499  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.400096
# 54500  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.407820
# ...           ...                                 ...        ...
# 81739  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.162025
# 81740  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.164173
# 81741  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.167371
# 81742  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.169859
# 81743  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.172087
#
#               Value       Power
# 54496  1.200125e+09         NaN
# 54497  1.200125e+09   86.477507
# 54498  1.200125e+09   74.083241
# 54499  1.200125e+09  118.216186
# 54500  1.200125e+09   89.935717
# ...             ...         ...
# 81739  1.200162e+09  118.784281
# 81740  1.200162e+09  122.670078
# 81741  1.200162e+09  116.742587
# 81742  1.200162e+09  119.982552
# 81743  1.200162e+09   88.373405
#
# [27248 rows x 5 columns]
# Run: trial_1-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 65.55% (432/659)
#   CrayPM > 100% TDP: 62.67% (413/659)
#   ROCm > 95% TDP: 36.05% (9823/27248)
#   ROCm > 100% TDP: 27.46% (7481/27248)
#             Group                         Metric Name       Time  \
# 53054  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.700271
# 53055  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.702886
# 53056  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.705156
# 53057  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.707767
# 53058  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.710161
# ...           ...                                 ...        ...
# 79576  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.855052
# 79577  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.858306
# 79578  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.861522
# 79579  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.863961
# 79580  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.866881
#
#               Value       Power
# 53054  1.943432e+09         NaN
# 53055  1.943432e+09  106.911270
# 53056  1.943432e+09   82.029535
# 53057  1.943432e+09  107.270238
# 53058  1.943432e+09   78.217056
# ...             ...         ...
# 79576  1.943471e+09  128.848445
# 79577  1.943471e+09  120.541311
# 79578  1.943471e+09  119.113187
# 79579  1.943471e+09  133.907345
# 79580  1.943471e+09  104.299785
#
# [26527 rows x 5 columns]
# Run: trial_1-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 64.16% (426/664)
#   CrayPM > 100% TDP: 47.74% (317/664)
#   ROCm > 95% TDP: 35.41% (9392/26527)
#   ROCm > 100% TDP: 28.49% (7557/26527)
#             Group                         Metric Name       Time  \
# 51112  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.207241
# 51113  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.211228
# 51114  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.214094
# 51115  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.231073
# 51116  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.234275
# ...           ...                                 ...        ...
# 76663  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.636599
# 76664  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.639824
# 76665  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.643054
# 76666  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.646597
# 76667  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.649092
#
#               Value       Power
# 51112  1.943471e+09         NaN
# 51113  1.943471e+09  100.668045
# 51114  1.943471e+09  105.235529
# 51115  1.943471e+09   99.640031
# 51116  1.943471e+09   91.133104
# ...             ...         ...
# 76663  1.943509e+09  124.514711
# 76664  1.943509e+09  162.511068
# 76665  1.943509e+09  130.054565
# 76666  1.943509e+09   98.513815
# 76667  1.943509e+09  122.364339
#
# [25556 rows x 5 columns]
# Run: trial_2-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 62.92% (414/658)
#   CrayPM > 100% TDP: 49.39% (325/658)
#   ROCm > 95% TDP: 33.89% (8662/25556)
#   ROCm > 100% TDP: 28.22% (7213/25556)
#             Group                         Metric Name       Time  \
# 45584  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.206994
# 45585  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.210992
# 45586  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.213843
# 45587  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.231915
# 45588  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.234055
# ...           ...                                 ...        ...
# 68371  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.801784
# 68372  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.806187
# 68373  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.811535
# 68374  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.814768
# 68375  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.817482
#
#               Value       Power
# 45584  1.200162e+09         NaN
# 45585  1.200162e+09   87.899428
# 45586  1.200162e+09  557.282753
# 45587  1.200162e+09   14.609680
# 45588  1.200162e+09   82.115419
# ...             ...         ...
# 68371  1.200199e+09  111.329810
# 68372  1.200199e+09  148.198094
# 68373  1.200199e+09  117.699578
# 68374  1.200199e+09  115.824856
# 68375  1.200199e+09  110.090666
#
# [22792 rows x 5 columns]
# Run: trial_2-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 67.79% (442/652)
#   CrayPM > 100% TDP: 66.56% (434/652)
#   ROCm > 95% TDP: 34.26% (7808/22792)
#   ROCm > 100% TDP: 27.00% (6154/22792)
#             Group                         Metric Name       Time  \
# 54496  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.390190
# 54497  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.393194
# 54498  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.397890
# 54499  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.400096
# 54500  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.407820
# ...           ...                                 ...        ...
# 81739  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.162025
# 81740  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.164173
# 81741  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.167371
# 81742  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.169859
# 81743  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.172087
#
#               Value       Power
# 54496  1.200125e+09         NaN
# 54497  1.200125e+09   86.477507
# 54498  1.200125e+09   74.083241
# 54499  1.200125e+09  118.216186
# 54500  1.200125e+09   89.935717
# ...             ...         ...
# 81739  1.200162e+09  118.784281
# 81740  1.200162e+09  122.670078
# 81741  1.200162e+09  116.742587
# 81742  1.200162e+09  119.982552
# 81743  1.200162e+09   88.373405
#
# [27248 rows x 5 columns]
# Run: trial_1-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 69.04% (455/659)
#   CrayPM > 100% TDP: 67.37% (444/659)
#   ROCm > 95% TDP: 36.05% (9823/27248)
#   ROCm > 100% TDP: 27.46% (7481/27248)
#             Group                         Metric Name       Time  \
# 53054  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.700271
# 53055  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.702886
# 53056  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.705156
# 53057  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.707767
# 53058  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.710161
# ...           ...                                 ...        ...
# 79576  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.855052
# 79577  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.858306
# 79578  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.861522
# 79579  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.863961
# 79580  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.866881
#
#               Value       Power
# 53054  1.943432e+09         NaN
# 53055  1.943432e+09  106.911270
# 53056  1.943432e+09   82.029535
# 53057  1.943432e+09  107.270238
# 53058  1.943432e+09   78.217056
# ...             ...         ...
# 79576  1.943471e+09  128.848445
# 79577  1.943471e+09  120.541311
# 79578  1.943471e+09  119.113187
# 79579  1.943471e+09  133.907345
# 79580  1.943471e+09  104.299785
#
# [26527 rows x 5 columns]
# Run: trial_1-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 65.51% (435/664)
#   CrayPM > 100% TDP: 18.37% (122/664)
#   ROCm > 95% TDP: 35.41% (9392/26527)
#   ROCm > 100% TDP: 28.49% (7557/26527)
#             Group                         Metric Name       Time  \
# 51112  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.207241
# 51113  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.211228
# 51114  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.214094
# 51115  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.231073
# 51116  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.234275
# ...           ...                                 ...        ...
# 76663  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.636599
# 76664  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.639824
# 76665  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.643054
# 76666  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.646597
# 76667  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.649092
#
#               Value       Power
# 51112  1.943471e+09         NaN
# 51113  1.943471e+09  100.668045
# 51114  1.943471e+09  105.235529
# 51115  1.943471e+09   99.640031
# 51116  1.943471e+09   91.133104
# ...             ...         ...
# 76663  1.943509e+09  124.514711
# 76664  1.943509e+09  162.511068
# 76665  1.943509e+09  130.054565
# 76666  1.943509e+09   98.513815
# 76667  1.943509e+09  122.364339
#
# [25556 rows x 5 columns]
# Run: trial_2-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 66.11% (433/655)
#   CrayPM > 100% TDP: 22.14% (145/655)
#   ROCm > 95% TDP: 33.89% (8662/25556)
#   ROCm > 100% TDP: 28.22% (7213/25556)
#             Group                         Metric Name       Time  \
# 45584  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.206994
# 45585  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.210992
# 45586  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.213843
# 45587  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.231915
# 45588  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.234055
# ...           ...                                 ...        ...
# 68371  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.801784
# 68372  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.806187
# 68373  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.811535
# 68374  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.814768
# 68375  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.817482
#
#               Value       Power
# 45584  1.200162e+09         NaN
# 45585  1.200162e+09   87.899428
# 45586  1.200162e+09  557.282753
# 45587  1.200162e+09   14.609680
# 45588  1.200162e+09   82.115419
# ...             ...         ...
# 68371  1.200199e+09  111.329810
# 68372  1.200199e+09  148.198094
# 68373  1.200199e+09  117.699578
# 68374  1.200199e+09  115.824856
# 68375  1.200199e+09  110.090666
#
# [22792 rows x 5 columns]
# Run: trial_2-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 66.72% (439/658)
#   CrayPM > 100% TDP: 62.16% (409/658)
#   ROCm > 95% TDP: 34.26% (7808/22792)
#   ROCm > 100% TDP: 27.00% (6154/22792)
#             Group                         Metric Name       Time  \
# 54496  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.390190
# 54497  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.393194
# 54498  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.397890
# 54499  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.400096
# 54500  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.407820
# ...           ...                                 ...        ...
# 81739  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.162025
# 81740  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.164173
# 81741  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.167371
# 81742  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.169859
# 81743  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.172087
#
#               Value       Power
# 54496  1.200125e+09         NaN
# 54497  1.200125e+09   86.477507
# 54498  1.200125e+09   74.083241
# 54499  1.200125e+09  118.216186
# 54500  1.200125e+09   89.935717
# ...             ...         ...
# 81739  1.200162e+09  118.784281
# 81740  1.200162e+09  122.670078
# 81741  1.200162e+09  116.742587
# 81742  1.200162e+09  119.982552
# 81743  1.200162e+09   88.373405
#
# [27248 rows x 5 columns]
# Run: trial_1-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 66.17% (440/665)
#   CrayPM > 100% TDP: 63.01% (419/665)
#   ROCm > 95% TDP: 36.05% (9823/27248)
#   ROCm > 100% TDP: 27.46% (7481/27248)
#             Group                         Metric Name       Time  \
# 53054  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.700271
# 53055  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.702886
# 53056  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.705156
# 53057  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.707767
# 53058  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.710161
# ...           ...                                 ...        ...
# 79576  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.855052
# 79577  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.858306
# 79578  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.861522
# 79579  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.863961
# 79580  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.866881
#
#               Value       Power
# 53054  1.943432e+09         NaN
# 53055  1.943432e+09  106.911270
# 53056  1.943432e+09   82.029535
# 53057  1.943432e+09  107.270238
# 53058  1.943432e+09   78.217056
# ...             ...         ...
# 79576  1.943471e+09  128.848445
# 79577  1.943471e+09  120.541311
# 79578  1.943471e+09  119.113187
# 79579  1.943471e+09  133.907345
# 79580  1.943471e+09  104.299785
#
# [26527 rows x 5 columns]
# Run: trial_1-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 64.42% (431/669)
#   CrayPM > 100% TDP: 23.77% (159/669)
#   ROCm > 95% TDP: 35.41% (9392/26527)
#   ROCm > 100% TDP: 28.49% (7557/26527)
#             Group                         Metric Name       Time  \
# 51112  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.207241
# 51113  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.211228
# 51114  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.214094
# 51115  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.231073
# 51116  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.234275
# ...           ...                                 ...        ...
# 76663  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.636599
# 76664  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.639824
# 76665  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.643054
# 76666  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.646597
# 76667  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.649092
#
#               Value       Power
# 51112  1.943471e+09         NaN
# 51113  1.943471e+09  100.668045
# 51114  1.943471e+09  105.235529
# 51115  1.943471e+09   99.640031
# 51116  1.943471e+09   91.133104
# ...             ...         ...
# 76663  1.943509e+09  124.514711
# 76664  1.943509e+09  162.511068
# 76665  1.943509e+09  130.054565
# 76666  1.943509e+09   98.513815
# 76667  1.943509e+09  122.364339
#
# [25556 rows x 5 columns]
# Run: trial_2-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 66.56% (436/655)
#   CrayPM > 100% TDP: 24.12% (158/655)
#   ROCm > 95% TDP: 33.89% (8662/25556)
#   ROCm > 100% TDP: 28.22% (7213/25556)
#             Group                         Metric Name       Time  \
# 45584  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.206994
# 45585  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.210992
# 45586  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.213843
# 45587  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.231915
# 45588  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.234055
# ...           ...                                 ...        ...
# 68371  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.801784
# 68372  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.806187
# 68373  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.811535
# 68374  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.814768
# 68375  MPI Rank 0  A2rocm_smi:::energy_count:device=2  82.817482
#
#               Value       Power
# 45584  1.200162e+09         NaN
# 45585  1.200162e+09   87.899428
# 45586  1.200162e+09  557.282753
# 45587  1.200162e+09   14.609680
# 45588  1.200162e+09   82.115419
# ...             ...         ...
# 68371  1.200199e+09  111.329810
# 68372  1.200199e+09  148.198094
# 68373  1.200199e+09  117.699578
# 68374  1.200199e+09  115.824856
# 68375  1.200199e+09  110.090666
#
# [22792 rows x 5 columns]
# Run: trial_2-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 67.53% (445/659)
#   CrayPM > 100% TDP: 64.49% (425/659)
#   ROCm > 95% TDP: 34.26% (7808/22792)
#   ROCm > 100% TDP: 27.00% (6154/22792)
#             Group                         Metric Name       Time  \
# 54496  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.390190
# 54497  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.393194
# 54498  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.397890
# 54499  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.400096
# 54500  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.407820
# ...           ...                                 ...        ...
# 81739  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.162025
# 81740  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.164173
# 81741  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.167371
# 81742  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.169859
# 81743  MPI Rank 0  A2rocm_smi:::energy_count:device=2  84.172087
#
#               Value       Power
# 54496  1.200125e+09         NaN
# 54497  1.200125e+09   86.477507
# 54498  1.200125e+09   74.083241
# 54499  1.200125e+09  118.216186
# 54500  1.200125e+09   89.935717
# ...             ...         ...
# 81739  1.200162e+09  118.784281
# 81740  1.200162e+09  122.670078
# 81741  1.200162e+09  116.742587
# 81742  1.200162e+09  119.982552
# 81743  1.200162e+09   88.373405
#
# [27248 rows x 5 columns]
# Run: trial_1-frontier10192-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 63.71% (416/653)
#   CrayPM > 100% TDP: 60.95% (398/653)
#   ROCm > 95% TDP: 36.05% (9823/27248)
#   ROCm > 100% TDP: 27.46% (7481/27248)
#             Group                         Metric Name       Time  \
# 53054  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.700271
# 53055  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.702886
# 53056  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.705156
# 53057  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.707767
# 53058  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.710161
# ...           ...                                 ...        ...
# 79576  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.855052
# 79577  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.858306
# 79578  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.861522
# 79579  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.863961
# 79580  MPI Rank 0  A2rocm_smi:::energy_count:device=2  87.866881
#
#               Value       Power
# 53054  1.943432e+09         NaN
# 53055  1.943432e+09  106.911270
# 53056  1.943432e+09   82.029535
# 53057  1.943432e+09  107.270238
# 53058  1.943432e+09   78.217056
# ...             ...         ...
# 79576  1.943471e+09  128.848445
# 79577  1.943471e+09  120.541311
# 79578  1.943471e+09  119.113187
# 79579  1.943471e+09  133.907345
# 79580  1.943471e+09  104.299785
#
# [26527 rows x 5 columns]
# Run: trial_1-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 66.03% (451/683)
#   CrayPM > 100% TDP: 53.73% (367/683)
#   ROCm > 95% TDP: 35.41% (9392/26527)
#   ROCm > 100% TDP: 28.49% (7557/26527)
#             Group                         Metric Name       Time  \
# 51112  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.207241
# 51113  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.211228
# 51114  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.214094
# 51115  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.231073
# 51116  MPI Rank 0  A2rocm_smi:::energy_count:device=2   0.234275
# ...           ...                                 ...        ...
# 76663  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.636599
# 76664  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.639824
# 76665  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.643054
# 76666  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.646597
# 76667  MPI Rank 0  A2rocm_smi:::energy_count:device=2  85.649092
#
#               Value       Power
# 51112  1.943471e+09         NaN
# 51113  1.943471e+09  100.668045
# 51114  1.943471e+09  105.235529
# 51115  1.943471e+09   99.640031
# 51116  1.943471e+09   91.133104
# ...             ...         ...
# 76663  1.943509e+09  124.514711
# 76664  1.943509e+09  162.511068
# 76665  1.943509e+09  130.054565
# 76666  1.943509e+09   98.513815
# 76667  1.943509e+09  122.364339
#
# [25556 rows x 5 columns]
# Run: trial_2-frontier09470-r8-rochpl--P_1_-Q_8_-N_245760, Node: node0
#   CrayPM > 95% TDP: 63.78% (435/682)
#   CrayPM > 100% TDP: 52.79% (360/682)
#   ROCm > 95% TDP: 33.89% (8662/25556)
#   ROCm > 100% TDP: 28.22% (7213/25556)
#             Group                         Metric Name       Time  \
# 22792  MPI Rank 0  A2rocm_smi:::energy_count:device=4   0.206994
# 22793  MPI Rank 0  A2rocm_smi:::energy_count:device=4   0.210992
# 22794  MPI Rank 0  A2rocm_smi:::energy_count:device=4   0.213843
# 22795  MPI Rank 0  A2rocm_smi:::energy_count:device=4   0.231915
# 22796  MPI Rank 0  A2rocm_smi:::energy_count:device=4   0.234055
# ...           ...                                 ...        ...
# ...
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.206708
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.210679
# ...           ...                                 ...        ...
# 14810  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.554586
# 14811  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.557038
# 14812  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.559628
# 14813  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.562055
# 14814  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.565403
#
#               Value       Power
# 0      1.899783e+09         NaN
# 1      1.899783e+09  103.863861
# 2      1.899783e+09  109.456265
# 3      1.899783e+09   93.005801
# 4      1.899783e+09   70.150321
# ...             ...         ...
# 14810  1.899791e+09   86.816253
# 14811  1.899791e+09  113.105035
# 14812  1.899791e+09   70.828666
# 14813  1.899791e+09  114.279062
# 14814  1.899791e+09   94.180035
#
# [14815 rows x 5 columns]
# Run: trial_1-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 3.09% (10/324)
#   CrayPM > 100% TDP: 1.85% (6/324)
#   ROCm > 95% TDP: 0.01% (1/14815)
#   ROCm > 100% TDP: 0.01% (1/14815)
#             Group                         Metric Name       Time  \
# 0      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.217120
# 1      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.228121
# 2      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.230585
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.233206
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.236426
# ...           ...                                 ...        ...
# 12984  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.627212
# 12985  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.630462
# 12986  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.633213
# 12987  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.635599
# 12988  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.638271
#
#               Value       Power
# 0      1.206772e+09         NaN
# 1      1.206772e+09   81.238066
# 2      1.206772e+09  108.775548
# 3      1.206772e+09   68.135011
# 4      1.206772e+09  110.980340
# ...             ...         ...
# 12984  1.206779e+09   71.613818
# 12985  1.206779e+09  110.903061
# 12986  1.206779e+09   65.903752
# 12987  1.206779e+09  113.917445
# 12988  1.206779e+09   81.611450
#
# [12989 rows x 5 columns]
# Run: trial_2-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 3.72% (12/323)
#   CrayPM > 100% TDP: 1.86% (6/323)
#   ROCm > 95% TDP: 0.00% (0/12989)
#   ROCm > 100% TDP: 0.00% (0/12989)
#             Group                         Metric Name       Time  \
# 0      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.218858
# 1      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.229860
# 2      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.232323
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.234889
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.237328
# ...           ...                                 ...        ...
# 14620  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.695864
# 14621  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.697852
# 14622  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.699844
# 14623  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.702803
# 14624  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.704943
#
#               Value       Power
# 0      1.899791e+09         NaN
# 1      1.899791e+09   83.653346
# 2      1.899791e+09  112.786755
# 3      1.899791e+09   71.395348
# 4      1.899791e+09  113.478245
# ...             ...         ...
# 14620  1.899798e+09   88.792252
# 14621  1.899798e+09   93.061621
# 14622  1.899798e+09  138.842124
# 14623  1.899798e+09   62.604639
# 14624  1.899798e+09  160.848972
#
# [14625 rows x 5 columns]
# Run: trial_2-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 2.50% (8/320)
#   CrayPM > 100% TDP: 0.94% (3/320)
#   ROCm > 95% TDP: 0.00% (0/14625)
#   ROCm > 100% TDP: 0.00% (0/14625)
#             Group                         Metric Name       Time  \
# 0      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.197581
# 1      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.200110
# 2      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.202702
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.205060
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.207720
# ...           ...                                 ...        ...
# 13137  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.363696
# 13138  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.367001
# 13139  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.369764
# 13140  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.372193
# 13141  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.375170
#
#               Value       Power
# 0      1.206765e+09         NaN
# 1      1.206765e+09  107.177824
# 2      1.206765e+09   69.827463
# 3      1.206765e+09  114.718904
# 4      1.206765e+09   68.329424
# ...             ...         ...
# 13137  1.206772e+09   84.298424
# 13138  1.206772e+09  109.084898
# 13139  1.206772e+09   65.672005
# 13140  1.206772e+09  140.692039
# 13141  1.206772e+09  124.934248
#
# [13142 rows x 5 columns]
# Run: trial_1-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 0.62% (2/323)
#   CrayPM > 100% TDP: 0.31% (1/323)
#   ROCm > 95% TDP: 0.00% (0/13142)
#   ROCm > 100% TDP: 0.00% (0/13142)
#             Group                         Metric Name       Time  \
# 0      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.197469
# 1      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.200141
# 2      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.202693
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.206708
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.210679
# ...           ...                                 ...        ...
# 14810  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.554586
# 14811  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.557038
# 14812  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.559628
# 14813  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.562055
# 14814  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.565403
#
#               Value       Power
# 0      1.899783e+09         NaN
# 1      1.899783e+09  103.863861
# 2      1.899783e+09  109.456265
# 3      1.899783e+09   93.005801
# 4      1.899783e+09   70.150321
# ...             ...         ...
# 14810  1.899791e+09   86.816253
# 14811  1.899791e+09  113.105035
# 14812  1.899791e+09   70.828666
# 14813  1.899791e+09  114.279062
# 14814  1.899791e+09   94.180035
#
# [14815 rows x 5 columns]
# Run: trial_1-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 1.22% (4/328)
#   CrayPM > 100% TDP: 0.30% (1/328)
#   ROCm > 95% TDP: 0.01% (1/14815)
#   ROCm > 100% TDP: 0.01% (1/14815)
#             Group                         Metric Name       Time  \
# 0      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.217120
# 1      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.228121
# 2      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.230585
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.233206
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.236426
# ...           ...                                 ...        ...
# 12984  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.627212
# 12985  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.630462
# 12986  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.633213
# 12987  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.635599
# 12988  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.638271
#
#               Value       Power
# 0      1.206772e+09         NaN
# 1      1.206772e+09   81.238066
# 2      1.206772e+09  108.775548
# 3      1.206772e+09   68.135011
# 4      1.206772e+09  110.980340
# ...             ...         ...
# 12984  1.206779e+09   71.613818
# 12985  1.206779e+09  110.903061
# 12986  1.206779e+09   65.903752
# 12987  1.206779e+09  113.917445
# 12988  1.206779e+09   81.611450
#
# [12989 rows x 5 columns]
# Run: trial_2-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 2.80% (9/321)
#   CrayPM > 100% TDP: 0.62% (2/321)
#   ROCm > 95% TDP: 0.00% (0/12989)
#   ROCm > 100% TDP: 0.00% (0/12989)
#             Group                         Metric Name       Time  \
# 0      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.218858
# 1      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.229860
# 2      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.232323
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.234889
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.237328
# ...           ...                                 ...        ...
# 14620  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.695864
# 14621  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.697852
# 14622  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.699844
# 14623  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.702803
# 14624  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.704943
#
#               Value       Power
# 0      1.899791e+09         NaN
# 1      1.899791e+09   83.653346
# 2      1.899791e+09  112.786755
# 3      1.899791e+09   71.395348
# 4      1.899791e+09  113.478245
# ...             ...         ...
# 14620  1.899798e+09   88.792252
# 14621  1.899798e+09   93.061621
# 14622  1.899798e+09  138.842124
# 14623  1.899798e+09   62.604639
# 14624  1.899798e+09  160.848972
#
# [14625 rows x 5 columns]
# Run: trial_2-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 2.20% (7/318)
#   CrayPM > 100% TDP: 0.63% (2/318)
#   ROCm > 95% TDP: 0.00% (0/14625)
#   ROCm > 100% TDP: 0.00% (0/14625)
#             Group                         Metric Name       Time  \
# 0      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.197581
# 1      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.200110
# 2      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.202702
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.205060
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.207720
# ...           ...                                 ...        ...
# 13137  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.363696
# 13138  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.367001
# 13139  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.369764
# 13140  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.372193
# 13141  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.375170
#
#               Value       Power
# 0      1.206765e+09         NaN
# 1      1.206765e+09  107.177824
# 2      1.206765e+09   69.827463
# 3      1.206765e+09  114.718904
# 4      1.206765e+09   68.329424
# ...             ...         ...
# 13137  1.206772e+09   84.298424
# 13138  1.206772e+09  109.084898
# 13139  1.206772e+09   65.672005
# 13140  1.206772e+09  140.692039
# 13141  1.206772e+09  124.934248
#
# [13142 rows x 5 columns]
# Run: trial_1-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 2.73% (9/330)
#   CrayPM > 100% TDP: 0.30% (1/330)
#   ROCm > 95% TDP: 0.00% (0/13142)
#   ROCm > 100% TDP: 0.00% (0/13142)
#             Group                         Metric Name       Time  \
# 0      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.197469
# 1      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.200141
# 2      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.202693
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.206708
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.210679
# ...           ...                                 ...        ...
# 14810  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.554586
# 14811  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.557038
# 14812  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.559628
# 14813  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.562055
# 14814  MPI Rank 0  A2rocm_smi:::energy_count:device=6  43.565403
#
#               Value       Power
# 0      1.899783e+09         NaN
# 1      1.899783e+09  103.863861
# 2      1.899783e+09  109.456265
# 3      1.899783e+09   93.005801
# 4      1.899783e+09   70.150321
# ...             ...         ...
# 14810  1.899791e+09   86.816253
# 14811  1.899791e+09  113.105035
# 14812  1.899791e+09   70.828666
# 14813  1.899791e+09  114.279062
# 14814  1.899791e+09   94.180035
#
# [14815 rows x 5 columns]
# Run: trial_1-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 2.37% (8/337)
#   CrayPM > 100% TDP: 1.48% (5/337)
#   ROCm > 95% TDP: 0.01% (1/14815)
#   ROCm > 100% TDP: 0.01% (1/14815)
#             Group                         Metric Name       Time  \
# 0      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.217120
# 1      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.228121
# 2      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.230585
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.233206
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.236426
# ...           ...                                 ...        ...
# 12984  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.627212
# 12985  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.630462
# 12986  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.633213
# 12987  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.635599
# 12988  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.638271
#
#               Value       Power
# 0      1.206772e+09         NaN
# 1      1.206772e+09   81.238066
# 2      1.206772e+09  108.775548
# 3      1.206772e+09   68.135011
# 4      1.206772e+09  110.980340
# ...             ...         ...
# 12984  1.206779e+09   71.613818
# 12985  1.206779e+09  110.903061
# 12986  1.206779e+09   65.903752
# 12987  1.206779e+09  113.917445
# 12988  1.206779e+09   81.611450
#
# [12989 rows x 5 columns]
# Run: trial_2-frontier10192-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 2.47% (8/324)
#   CrayPM > 100% TDP: 0.00% (0/324)
#   ROCm > 95% TDP: 0.00% (0/12989)
#   ROCm > 100% TDP: 0.00% (0/12989)
#             Group                         Metric Name       Time  \
# 0      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.218858
# 1      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.229860
# 2      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.232323
# 3      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.234889
# 4      MPI Rank 0  A2rocm_smi:::energy_count:device=6   0.237328
# ...           ...                                 ...        ...
# 14620  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.695864
# 14621  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.697852
# 14622  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.699844
# 14623  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.702803
# 14624  MPI Rank 0  A2rocm_smi:::energy_count:device=6  42.704943
#
#               Value       Power
# 0      1.899791e+09         NaN
# 1      1.899791e+09   83.653346
# 2      1.899791e+09  112.786755
# 3      1.899791e+09   71.395348
# 4      1.899791e+09  113.478245
# ...             ...         ...
# 14620  1.899798e+09   88.792252
# 14621  1.899798e+09   93.061621
# 14622  1.899798e+09  138.842124
# 14623  1.899798e+09   62.604639
# 14624  1.899798e+09  160.848972
#
# [14625 rows x 5 columns]
# Run: trial_2-frontier09470-r8-xhpgmp-128_128_128_--run_type=standalone_mxp, Node: node0
#   CrayPM > 95% TDP: 2.18% (7/321)
#   CrayPM > 100% TDP: 0.93% (3/321)
#   ROCm > 95% TDP: 0.00% (0/14625)
#   ROCm > 100% TDP: 0.00% (0/14625)

# %%
# Get the end time of the notebook
NOTEBOOK_END_TIME = time.time()
print(f"Notebook end time: {NOTEBOOK_END_TIME}")
print(f"Notebook end at {NOTEBOOK_END_TIME} ({datetime.datetime.fromtimestamp(NOTEBOOK_END_TIME)})")

NOTEBOOK_DURATION = NOTEBOOK_END_TIME - NOTEBOOK_START_TIME
print(f"Notebook execution time: {NOTEBOOK_DURATION:.2f} seconds")
# Out:
# Notebook end time: 1760639955.1252291
# Notebook end at 1760639955.1252291 (2025-10-16 14:39:15.125229)
# Notebook execution time: 137.19 seconds

# %%
# Remove csv files to save space
for path in os.listdir('.'):
    if path.endswith('.csv'):
        os.remove(path)
        print(f"Removed file: {path}")
# Out:
# Removed file: MPI Rank 1_metrics.csv
# Removed file: MPI Rank 2_Master_thread_callgraph.csv
# Removed file: MPI Rank 7_Master_thread_callgraph.csv
# Removed file: MPI Rank 0_UnknownLocation_callgraph.csv
# Removed file: MPI Rank 4_metrics.csv
# Removed file: MPI Rank 7_metrics.csv
# Removed file: MPI Rank 6_Master_thread_callgraph.csv
# Removed file: MPI Rank 3_Master_thread_callgraph.csv
# Removed file: MPI Rank 2_metrics.csv
# Removed file: MPI Rank 0_Master_thread_callgraph.csv
# Removed file: MPI Rank 5_metrics.csv
# Removed file: MPI Rank 5_Master_thread_callgraph.csv
# Removed file: MPI Rank 0_metrics.csv
# Removed file: MPI Rank 4_Master_thread_callgraph.csv
# Removed file: MPI Rank 3_metrics.csv
# Removed file: MPI Rank 1_Master_thread_callgraph.csv
# Removed file: MPI Rank 6_metrics.csv
